# %%
import requests
import json
import numpy as np

def getAddress(x, y):
  # 1. API 기본 정보 설정
  URL = "https://dapi.kakao.com/v2/local/geo/coord2regioncode.json"
  API_KEY = "xxxx" # 실제 API 키로 대체 필요

  # 2. 헤더 설정 (인증 키 포함)
  headers = {
    "Authorization": f"KakaoAK {API_KEY}"
  }

  # 3. 쿼리 파라미터 설정
  # 'x'와 'y'는 URL에 직접 포함되거나 params로 전달 가능합니다.
  params = {
    "x": x,
    "y": y
  }

  # 4. GET 요청 보내기
  try:
    response = requests.get(URL, headers=headers, params=params)
    
    # HTTP 상태 코드 확인
    response.raise_for_status()
    
    # 5. JSON 응답 출력
    data = response.json()
    # 한글 깨짐 없이, 보기 좋게 들여쓰기하여 출력
    json_obj = json.dumps(data, indent=2, ensure_ascii=False)
    #print(json_obj)
    #print(data['documents'][0]['region_1depth_name'])
    #print(data['documents'][0]['region_2depth_name'])
    #print(data['documents'][0]['region_3depth_name'])
    
    return data['documents'][0]['region_1depth_name'], data['documents'][0]['region_2depth_name'], data['documents'][0]['region_3depth_name']

  except requests.exceptions.RequestException as e:
    print(f"API 요청 오류 발생: {e}")
    if 'response' in locals():
      print(f"응답 상태 코드: {response.status_code}")
      print(f"응답 본문: {response.text}")
      
    return np.nan, np.nan, np.nan

# %%
print(getAddress(126.9079339, 37.64672726))
# Out:
# ('서울특별시', '은평구', '진관동')

# %%
import pandas as pd
import numpy as np

src_df = pd.read_csv('서울시버스노선별정류소정보(20251002) - Data.csv')

# %%
src_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41261 entries, 0 to 41260
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ROUTE_ID  41261 non-null  int64
#  1   노선명       41261 non-null  object
#  2   순번        41261 non-null  int64
#  3   NODE_ID   41261 non-null  int64
#  4   ARS_ID    41261 non-null  int64
#  5   정류소명      41261 non-null  object
#  6   X좌표       41261 non-null  float64
#  7   Y좌표       41261 non-null  float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 2.5+ MB

# %%
src_df['시'] = np.nan
src_df['구'] = np.nan
src_df['동'] = np.nan

# %%
src_df.head()
# Out:
#     ROUTE_ID   노선명  순번    NODE_ID  ARS_ID         정류소명       X좌표        Y좌표  \
# 0  100100407   240   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 1  100100049   273   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 2  100100186  2012   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 3  100100190  2015   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 4  100100599  2311   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
#
#     시   구   동
# 0 NaN NaN NaN
# 1 NaN NaN NaN
# 2 NaN NaN NaN
# 3 NaN NaN NaN
# 4 NaN NaN NaN

# %%
import pandas as pd
import requests
import time
import json
from io import StringIO
from math import isnan # NaN 값 비교를 위해 임포트

# %%
# 3. API 결과를 저장할 딕셔너리 초기화
# 키: (x, y) 튜플, 값: {'a': a_val, 'b': b_val, 'c': c_val}
api_cache = {}

# 4. API 호출 대상 좌표 목록 추출
# 'a' 컬럼 값이 NaN인 행을 필터링하고, 'x', 'y' 컬럼의 중복을 제거합니다.
# isnan을 사용해 NaN인지 확인
coords_to_query = (
    src_df[src_df['시'].apply(lambda x: isnan(x) if pd.notna(x) else True)] # 'a'가 NaN인 행 필터링
    [['X좌표', 'Y좌표']]
    .drop_duplicates()
    .itertuples(index=False, name=None)
)

coords_list = list(coords_to_query)
print(f"API 호출이 필요한 고유 좌표 쌍: {len(coords_list)}개")
# Out:
# API 호출이 필요한 고유 좌표 쌍: 12894개

# %%
# 5. 고유 좌표에 대해서만 API 호출
# 다음 실행할때는 tqdm 쓰고 로그는 제거하자
for x_val, y_val in coords_list:
    coord_key = (x_val, y_val)
    #print(f"\n📡 API 호출 시작: x={x_val}, y={y_val}")
    
    try:
        # NOTE: 응답 구조에 맞게 수정 필요
        a_val, b_val, c_val = getAddress(x_val, y_val)
        
        # 4. 캐시에 결과 저장
        api_cache[coord_key] = {'시': a_val, '구': b_val, '동': c_val}
        #print(f"✅ 처리 완료. 결과: 시={a_val}, 구={b_val}, 동={c_val}")

    except Exception as e:
        print(f"❌ 처리 중 오류 발생 ({coord_key}): {e}")
        api_cache[coord_key] = {'a': None, 'b': None, 'c': None, 'api_status': f"Error: {str(e)}"}
        
    # API 호출 제한 방지를 위한 지연 시간 (필수 권장!)
    time.sleep(0.5)
# Out:
# 📡 API 호출 시작: x=127.1027997, y=37.61354475
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=신내동
#
# 📡 API 호출 시작: x=127.0407624, y=37.65893642
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=126.969153, y=37.556235
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=만리동1가
#
# 📡 API 호출 시작: x=126.93783, y=37.46571
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.9398176, y=37.47037897
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.919247, y=37.489233
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.0503112, y=37.62754013
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.956215, y=37.491679
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.892827, y=37.490156
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.9572808, y=37.49531836
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.92119, y=37.453078
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.1762683, y=37.3455333
# ✅ 처리 완료. 결과: 시=경기도, 구=광주시, 동=능평동
#
# 📡 API 호출 시작: x=126.8688211, y=37.49056774
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=철산동
#
# 📡 API 호출 시작: x=126.8688129, y=37.49065738
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=철산동
#
# 📡 API 호출 시작: x=126.989289, y=37.55974
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=예장동
#
# 📡 API 호출 시작: x=127.12764, y=37.469822
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=126.9880882, y=37.46569518
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=126.80188, y=37.562495
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=방화동
#
# 📡 API 호출 시작: x=126.96306, y=37.53216
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=한강로3가
#
# 📡 API 호출 시작: x=126.906143, y=37.612225
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=구산동
#
# 📡 API 호출 시작: x=126.9236679, y=37.55732547
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=동교동
#
# 📡 API 호출 시작: x=126.923439, y=37.557726
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=동교동
#
# 📡 API 호출 시작: x=126.956245, y=37.557136
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=아현동
#
# 📡 API 호출 시작: x=126.8855596, y=37.43604157
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=소하동
#
# 📡 API 호출 시작: x=127.0272458, y=37.59856235
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=종암동
#
# 📡 API 호출 시작: x=126.9563755, y=37.30237501
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=126.9541673, y=37.54438686
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=신공덕동
#
# 📡 API 호출 시작: x=126.84379, y=37.493629
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=오류동
#
# 📡 API 호출 시작: x=126.7597055, y=37.68636827
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=대화동
#
# 📡 API 호출 시작: x=126.904886, y=37.513267
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=영등포동
#
# 📡 API 호출 시작: x=127.0008807, y=37.45140715
# ✅ 처리 완료. 결과: 시=경기도, 구=과천시, 동=과천동
#
# 📡 API 호출 시작: x=127.0985695, y=37.82944006
# ✅ 처리 완료. 결과: 시=경기도, 구=양주시, 동=옥정동
#
# 📡 API 호출 시작: x=126.8328096, y=37.63444981
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=화정동
#
# 📡 API 호출 시작: x=127.064041, y=37.478975
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=127.1180291, y=37.74955994
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9033765, y=37.43355165
# ✅ 처리 완료. 결과: 시=경기도, 구=안양시 만안구, 동=석수동
#
# 📡 API 호출 시작: x=126.91173, y=37.450409
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.909455, y=37.462545
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.157278, y=37.49096
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=126.8213322, y=37.54520915
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=외발산동
#
# 📡 API 호출 시작: x=126.8503821, y=37.51157732
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=127.06447, y=37.627618
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=127.070635, y=37.637536
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=하계동
#
# 📡 API 호출 시작: x=127.0822757, y=37.67083422
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.1849817, y=37.55013755
# ✅ 처리 완료. 결과: 시=경기도, 구=하남시, 동=풍산동
#
# 📡 API 호출 시작: x=127.102535, y=37.465344
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=세곡동
#
# 📡 API 호출 시작: x=127.0665, y=37.610699
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=석관동
#
# 📡 API 호출 시작: x=127.065628, y=37.611267
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=석관동
#
# 📡 API 호출 시작: x=126.8996741, y=37.57520782
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.1089104, y=37.64666044
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=127.015601, y=37.484755
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=126.9617068, y=37.59813307
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=부암동
#
# 📡 API 호출 시작: x=126.900601, y=37.579265
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=증산동
#
# 📡 API 호출 시작: x=127.044525, y=37.651106
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=127.1563936, y=37.59361679
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=126.88381, y=37.591802
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=수색동
#
# 📡 API 호출 시작: x=126.8915708, y=37.50701588
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.9056673, y=37.64685893
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=동산동
#
# 📡 API 호출 시작: x=126.875255, y=37.48522703
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=126.9108336, y=37.6088024
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=구산동
#
# 📡 API 호출 시작: x=126.99237, y=37.587863
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=명륜3가
#
# 📡 API 호출 시작: x=126.9263634, y=37.51258813
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=대방동
#
# 📡 API 호출 시작: x=127.063217, y=37.480651
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=127.069256, y=37.483766
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.909608, y=37.614378
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=구산동
#
# 📡 API 호출 시작: x=126.9826144, y=37.49423389
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=동작동
#
# 📡 API 호출 시작: x=126.82122, y=37.491968
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=온수동
#
# 📡 API 호출 시작: x=126.747558, y=37.4887844
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.011738, y=37.663032
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=127.013707, y=37.632628
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=126.963882, y=37.53259
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=한강로3가
#
# 📡 API 호출 시작: x=127.0352743, y=37.63495684
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=126.929633, y=37.485847
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.919021, y=37.464132
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.055682, y=37.535793
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=성수동2가
#
# 📡 API 호출 시작: x=126.924317, y=37.557325
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=동교동
#
# 📡 API 호출 시작: x=127.006498, y=37.620221
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=126.926049, y=37.513513
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=126.919402, y=37.498862
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=127.135886, y=37.480507
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=126.908325, y=37.646847
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=127.0858494, y=37.57577456
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.084205, y=37.572917
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.0841788, y=37.57315089
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=126.946105, y=37.570102
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=봉원동
#
# 📡 API 호출 시작: x=126.910257, y=37.581632
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=127.0457253, y=37.68858174
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=도봉동
#
# 📡 API 호출 시작: x=126.9079339, y=37.64672726
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=127.151301, y=37.494369
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=거여동
#
# 📡 API 호출 시작: x=127.0064557, y=37.59670335
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=돈암동
#
# 📡 API 호출 시작: x=127.011423, y=37.61546
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.025549, y=37.50153192
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.087052, y=37.562118
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=중곡동
#
# 📡 API 호출 시작: x=126.9940273, y=37.61067955
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.00006, y=37.60863
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.002908, y=37.607386
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=126.896317, y=37.566664
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=성산동
#
# 📡 API 호출 시작: x=127.01802, y=37.657407
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=126.8831991, y=37.48143938
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=126.883688, y=37.510209
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=신도림동
#
# 📡 API 호출 시작: x=127.046268, y=37.580477
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=전농동
#
# 📡 API 호출 시작: x=127.092596, y=37.59866073
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=상봉동
#
# 📡 API 호출 시작: x=127.040722, y=37.687083
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=도봉동
#
# 📡 API 호출 시작: x=127.1746744, y=37.57247694
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=126.838533, y=37.44168542
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=노온사동
#
# 📡 API 호출 시작: x=126.817092, y=37.477579
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=항동
#
# 📡 API 호출 시작: x=127.051155, y=37.545895
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=성수동2가
#
# 📡 API 호출 시작: x=126.91589, y=37.50425862
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=127.035298, y=37.551878
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=응봉동
#
# 📡 API 호출 시작: x=127.181785, y=37.56003
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=127.1275898, y=37.46992977
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=126.7694821, y=37.66405609
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=정발산동
#
# 📡 API 호출 시작: x=127.015178, y=37.619548
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=127.074911, y=37.530442
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=자양동
#
# 📡 API 호출 시작: x=127.0768713, y=37.53270034
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=자양동
#
# 📡 API 호출 시작: x=127.173885, y=37.564066
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=127.078165, y=37.566876
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=중곡동
#
# 📡 API 호출 시작: x=127.0443522, y=37.68994836
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=도봉동
#
# 📡 API 호출 시작: x=126.8725664, y=37.45806545
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=하안동
#
# 📡 API 호출 시작: x=126.7642727, y=37.69339342
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=127.0505519, y=37.61950399
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=126.936464, y=37.609607
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=녹번동
#
# 📡 API 호출 시작: x=126.891835, y=37.499974
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.890072, y=37.488807
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.1791507, y=37.43560669
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1231805, y=37.3698934
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=수내동
#
# 📡 API 호출 시작: x=127.1098466, y=37.49629776
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=가락동
#
# 📡 API 호출 시작: x=127.0068383, y=37.64566705
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.0637357, y=37.66027786
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.875258, y=37.568751
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.0361604, y=37.63423504
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=126.4340182, y=37.46650468
# ✅ 처리 완료. 결과: 시=인천광역시, 구=중구, 동=운서동
#
# 📡 API 호출 시작: x=126.9979441, y=37.61391999
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.0101775, y=37.61294369
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.0164517, y=37.59229187
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=동소문동5가
#
# 📡 API 호출 시작: x=127.0164202, y=37.61422433
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=길음동
#
# 📡 API 호출 시작: x=127.0451512, y=37.61994503
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=127.0405011, y=37.61190904
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=127.0437264, y=37.61658542
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=126.8587649, y=37.49501638
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=127.009674, y=37.601537
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=126.8421808, y=37.47944324
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=천왕동
#
# 📡 API 호출 시작: x=126.846905, y=37.50797
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=고척동
#
# 📡 API 호출 시작: x=127.0122905, y=37.66343097
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=127.0602824, y=37.67463564
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.0571173, y=37.64216054
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.051943, y=37.666974
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.0664538, y=37.66671546
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.0169984, y=37.54185375
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=옥수동
#
# 📡 API 호출 시작: x=126.974305, y=37.576715
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=세종로
#
# 📡 API 호출 시작: x=127.140918, y=37.50685
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=오금동
#
# 📡 API 호출 시작: x=127.026824, y=37.560369
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=하왕십리동
#
# 📡 API 호출 시작: x=127.0110779, y=37.60460856
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=126.9506449, y=37.41054027
# ✅ 처리 완료. 결과: 시=경기도, 구=안양시 동안구, 동=비산동
#
# 📡 API 호출 시작: x=126.944217, y=37.599114
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.8179353, y=37.54533512
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=외발산동
#
# 📡 API 호출 시작: x=126.915263, y=37.633821
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=126.8505011, y=37.67036811
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=원당동
#
# 📡 API 호출 시작: x=126.89647, y=37.566631
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=성산동
#
# 📡 API 호출 시작: x=127.170216, y=37.563645
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=고덕동
#
# 📡 API 호출 시작: x=126.915964, y=37.448241
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.978207, y=37.569011
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=무교동
#
# 📡 API 호출 시작: x=127.100588, y=37.488469
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=수서동
#
# 📡 API 호출 시작: x=127.1479321, y=37.48159788
# ✅ 처리 완료. 결과: 시=경기도, 구=하남시, 동=학암동
#
# 📡 API 호출 시작: x=126.7244045, y=37.60959491
# ✅ 처리 완료. 결과: 시=경기도, 구=김포시, 동=풍무동
#
# 📡 API 호출 시작: x=127.0948099, y=37.41122367
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=시흥동
#
# 📡 API 호출 시작: x=127.0410543, y=37.75519388
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=가능동
#
# 📡 API 호출 시작: x=126.858684, y=37.49388204
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=126.816664, y=37.555154
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=공항동
#
# 📡 API 호출 시작: x=127.011523, y=37.662868
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=126.886128, y=37.41869513
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=일직동
#
# 📡 API 호출 시작: x=127.1058277, y=37.34198293
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=구미동
#
# 📡 API 호출 시작: x=127.065197, y=37.61493
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=127.052187, y=37.635412
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.7222249, y=37.69485104
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=가좌동
#
# 📡 API 호출 시작: x=126.955143, y=37.601417
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=홍지동
#
# 📡 API 호출 시작: x=126.8738198, y=37.63707855
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=원흥동
#
# 📡 API 호출 시작: x=127.117779, y=37.74709301
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=127.0531389, y=37.69023692
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=장암동
#
# 📡 API 호출 시작: x=126.7191819, y=37.72444428
# ✅ 처리 완료. 결과: 시=경기도, 구=파주시, 동=동패동
#
# 📡 API 호출 시작: x=126.8542039, y=37.55892751
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=등촌동
#
# 📡 API 호출 시작: x=126.7906902, y=37.71630638
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=설문동
#
# 📡 API 호출 시작: x=127.019985, y=37.546215
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=금호동4가
#
# 📡 API 호출 시작: x=127.0154199, y=37.61909483
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=127.0670672, y=37.66436871
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.933839, y=37.5956
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9587733, y=37.56583701
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=천연동
#
# 📡 API 호출 시작: x=126.9241991, y=37.56957653
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=연희동
#
# 📡 API 호출 시작: x=126.9492611, y=37.55912016
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북아현동
#
# 📡 API 호출 시작: x=126.943324, y=37.582426
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍제동
#
# 📡 API 호출 시작: x=126.949851, y=37.605675
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9344518, y=37.58041378
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9585131, y=37.56590986
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북아현동
#
# 📡 API 호출 시작: x=126.9529748, y=37.56480507
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북아현동
#
# 📡 API 호출 시작: x=126.9360671, y=37.58488227
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍제동
#
# 📡 API 호출 시작: x=126.9539148, y=37.58979768
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍제동
#
# 📡 API 호출 시작: x=126.9285294, y=37.58483559
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9317244, y=37.58643602
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9478811, y=37.5358266
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=도화동
#
# 📡 API 호출 시작: x=126.879876, y=37.580411
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.935896, y=37.554288
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=노고산동
#
# 📡 API 호출 시작: x=126.9359752, y=37.55469925
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=노고산동
#
# 📡 API 호출 시작: x=126.8988594, y=37.5608656
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=망원동
#
# 📡 API 호출 시작: x=126.8985925, y=37.55649687
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=망원동
#
# 📡 API 호출 시작: x=126.9119308, y=37.54564037
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=합정동
#
# 📡 API 호출 시작: x=126.8680475, y=37.54903807
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=목동
#
# 📡 API 호출 시작: x=126.828095, y=37.515057
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=126.8806238, y=37.58105871
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.906723, y=37.463855
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.894201, y=37.494421
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.8820034, y=37.51008302
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=신도림동
#
# 📡 API 호출 시작: x=126.843812, y=37.493467
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=오류동
#
# 📡 API 호출 시작: x=126.8581281, y=37.49503364
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=126.8520773, y=37.48604673
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=126.8586856, y=37.4951118
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=126.8761587, y=37.49295615
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.0085998, y=37.59434268
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=돈암동
#
# 📡 API 호출 시작: x=127.013573, y=37.585159
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=삼선동3가
#
# 📡 API 호출 시작: x=127.0112286, y=37.58256252
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=삼선동2가
#
# 📡 API 호출 시작: x=126.891884, y=37.507635
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.911353, y=37.583707
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=126.9951882, y=37.48832883
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=127.1238374, y=37.18646207
# ✅ 처리 완료. 결과: 시=경기도, 구=화성시, 동=목동
#
# 📡 API 호출 시작: x=126.9253683, y=37.33192241
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=부곡동
#
# 📡 API 호출 시작: x=126.9520773, y=37.4487952
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.0145108, y=37.48784332
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.012719, y=37.662647
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=127.013357, y=37.662045
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=126.9122339, y=37.61427123
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=갈현동
#
# 📡 API 호출 시작: x=127.07827, y=37.493332
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=일원동
#
# 📡 API 호출 시작: x=127.101871, y=37.461224
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=세곡동
#
# 📡 API 호출 시작: x=127.094527, y=37.466836
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=세곡동
#
# 📡 API 호출 시작: x=127.053878, y=37.47599
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=127.089059, y=37.481418
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=수서동
#
# 📡 API 호출 시작: x=127.0176125, y=37.54181185
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=옥수동
#
# 📡 API 호출 시작: x=126.836678, y=37.575737
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=마곡동
#
# 📡 API 호출 시작: x=126.818103, y=37.553498
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=외발산동
#
# 📡 API 호출 시작: x=126.8516393, y=37.53877765
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=126.8892263, y=37.46700017
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=독산동
#
# 📡 API 호출 시작: x=126.917506, y=37.453382
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.88771, y=37.45657923
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=독산동
#
# 📡 API 호출 시작: x=126.897101, y=37.451425
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.157155, y=37.490972
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=127.1466291, y=37.49852935
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=127.079314, y=37.482544
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=일원동
#
# 📡 API 호출 시작: x=127.174627, y=37.564251
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=126.911018, y=37.477083
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=독산동
#
# 📡 API 호출 시작: x=126.882956, y=37.481315
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=126.837646, y=37.508701
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=126.9196774, y=37.46528249
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.1369279, y=37.4806082
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=127.0499898, y=37.65397438
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=127.063365, y=37.656202
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.797978, y=37.57822
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=개화동
#
# 📡 API 호출 시작: x=127.1060443, y=37.34226629
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=구미동
#
# 📡 API 호출 시작: x=127.030351, y=37.62890113
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=127.0395643, y=37.62899212
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=127.0127201, y=37.62417727
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=126.9353907, y=37.5814082
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9280833, y=37.57574802
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=연희동
#
# 📡 API 호출 시작: x=126.940108, y=37.499156
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.937427, y=37.471078
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.928182, y=37.4999673
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=대방동
#
# 📡 API 호출 시작: x=126.9806262, y=37.48500144
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.9408686, y=37.496166
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.9724841, y=37.48615684
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.936319, y=37.49376893
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.960569, y=37.500332
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=흑석동
#
# 📡 API 호출 시작: x=126.9627803, y=37.48913684
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.97115, y=37.489628
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.9815811, y=37.47868741
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.9598585, y=37.49956344
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=흑석동
#
# 📡 API 호출 시작: x=126.954474, y=37.512428
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=본동
#
# 📡 API 호출 시작: x=127.0369827, y=37.56105361
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=행당동
#
# 📡 API 호출 시작: x=126.9740958, y=37.49168729
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=127.104668, y=37.612974
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=망우동
#
# 📡 API 호출 시작: x=126.960694, y=37.499535
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=흑석동
#
# 📡 API 호출 시작: x=126.98242, y=37.48721
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=126.8784199, y=37.58114971
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.0428812, y=37.45426839
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=원지동
#
# 📡 API 호출 시작: x=127.024081, y=37.45950105
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=우면동
#
# 📡 API 호출 시작: x=127.0636983, y=37.45471003
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=내곡동
#
# 📡 API 호출 시작: x=127.0670298, y=37.51285422
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=삼성동
#
# 📡 API 호출 시작: x=127.061071, y=37.476907
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=127.050172, y=37.65365769
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=127.083058, y=37.644643
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=중계동
#
# 📡 API 호출 시작: x=127.09538, y=37.586485
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=126.8802387, y=37.57740124
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.8133545, y=37.57930827
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=방화동
#
# 📡 API 호출 시작: x=127.0551905, y=37.62792256
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=127.064485, y=37.659298
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=127.0509549, y=37.67171784
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.833838, y=37.52179
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신월동
#
# 📡 API 호출 시작: x=126.8257795, y=37.52345522
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신월동
#
# 📡 API 호출 시작: x=126.941712, y=37.48333412
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=127.058892, y=37.509275
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=삼성동
#
# 📡 API 호출 시작: x=127.0578477, y=37.59012302
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=휘경동
#
# 📡 API 호출 시작: x=127.072077, y=37.58455
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=휘경동
#
# 📡 API 호출 시작: x=127.0531915, y=37.56676846
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=답십리동
#
# 📡 API 호출 시작: x=127.0365261, y=37.59048339
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=제기동
#
# 📡 API 호출 시작: x=127.0087216, y=37.58040372
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=창신동
#
# 📡 API 호출 시작: x=126.9928637, y=37.59094838
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=명륜3가
#
# 📡 API 호출 시작: x=126.964469, y=37.582082
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=옥인동
#
# 📡 API 호출 시작: x=126.9981568, y=37.57895147
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=연건동
#
# 📡 API 호출 시작: x=126.9663939, y=37.56633706
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=평동
#
# 📡 API 호출 시작: x=126.9668167, y=37.60568122
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=평창동
#
# 📡 API 호출 시작: x=126.985123, y=37.57895
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=재동
#
# 📡 API 호출 시작: x=126.9816469, y=37.58822768
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=삼청동
#
# 📡 API 호출 시작: x=126.9900036, y=37.58846387
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=명륜3가
#
# 📡 API 호출 시작: x=126.9033112, y=37.43552416
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.0164273, y=37.54842402
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=금호동4가
#
# 📡 API 호출 시작: x=127.0204908, y=37.55459318
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=금호동1가
#
# 📡 API 호출 시작: x=126.918503, y=37.637573
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=127.070056, y=37.63813
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=하계동
#
# 📡 API 호출 시작: x=127.0218267, y=37.51679281
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=논현동
#
# 📡 API 호출 시작: x=126.9237906, y=37.51276936
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=127.0142947, y=37.45723906
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=우면동
#
# 📡 API 호출 시작: x=127.0729326, y=37.48765266
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.999296, y=37.617721
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.003343, y=37.616712
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.006345, y=37.613529
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.0348445, y=37.50037703
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=역삼동
#
# 📡 API 호출 시작: x=127.0137374, y=37.49417187
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.1688783, y=37.57651372
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=126.9248319, y=37.47607349
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.940902, y=37.483597
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.941744, y=37.491065
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.9686577, y=37.46931873
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.9304689, y=37.47525514
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.9606641, y=37.48558671
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.9189073, y=37.46347841
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.9619752, y=37.47707918
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.911063, y=37.47207654
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.016922, y=37.553522
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=금호동2가
#
# 📡 API 호출 시작: x=127.003953, y=37.533377
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=한남동
#
# 📡 API 호출 시작: x=126.9969933, y=37.54066038
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=이태원동
#
# 📡 API 호출 시작: x=127.0143208, y=37.54075326
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=옥수동
#
# 📡 API 호출 시작: x=127.0430257, y=37.57016549
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=마장동
#
# 📡 API 호출 시작: x=127.0825318, y=37.60006038
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=중화동
#
# 📡 API 호출 시작: x=127.1019812, y=37.58764536
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.0305164, y=37.61040992
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=127.0376226, y=37.63165635
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=127.0063794, y=37.63810131
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.0020125, y=37.64204009
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.010183, y=37.627439
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=126.8748583, y=37.58093599
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=덕은동
#
# 📡 API 호출 시작: x=126.9421197, y=37.48323621
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=127.013588, y=37.63211
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.0478487, y=37.60623486
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=상월곡동
#
# 📡 API 호출 시작: x=127.047211, y=37.468475
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=염곡동
#
# 📡 API 호출 시작: x=126.938321, y=37.470982
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.886709, y=37.515548
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=문래동5가
#
# 📡 API 호출 시작: x=126.887724, y=37.508551
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=신도림동
#
# 📡 API 호출 시작: x=126.8949855, y=37.49418817
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=대림동
#
# 📡 API 호출 시작: x=126.8962827, y=37.53174087
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=당산동4가
#
# 📡 API 호출 시작: x=126.8895618, y=37.5439176
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=양평동6가
#
# 📡 API 호출 시작: x=126.9010481, y=37.53300289
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=당산동5가
#
# 📡 API 호출 시작: x=126.9192632, y=37.46467082
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.135317, y=37.506195
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=오금동
#
# 📡 API 호출 시작: x=127.06408, y=37.492458
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=대치동
#
# 📡 API 호출 시작: x=126.910862, y=37.613895
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=구산동
#
# 📡 API 호출 시작: x=127.0302538, y=37.6628827
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=방학동
#
# 📡 API 호출 시작: x=127.0252306, y=37.65069499
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=127.0224988, y=37.65275721
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=127.0284575, y=37.64586897
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=126.9060258, y=37.59950075
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=신사동
#
# 📡 API 호출 시작: x=126.9139681, y=37.62926614
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=갈현동
#
# 📡 API 호출 시작: x=126.9337169, y=37.62258154
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=불광동
#
# 📡 API 호출 시작: x=126.9064059, y=37.60981269
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=구산동
#
# 📡 API 호출 시작: x=126.9253747, y=37.58834248
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=응암동
#
# 📡 API 호출 시작: x=126.8737556, y=37.54729799
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=염창동
#
# 📡 API 호출 시작: x=126.818551, y=37.583442
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=방화동
#
# 📡 API 호출 시작: x=126.8578071, y=37.53253613
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=126.851516, y=37.538286
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=127.043825, y=37.466093
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=염곡동
#
# 📡 API 호출 시작: x=126.9852046, y=37.49727424
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=127.086699, y=37.459688
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=내곡동
#
# 📡 API 호출 시작: x=127.014737, y=37.49379959
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.013341, y=37.48042
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=126.990307, y=37.498382
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=반포동
#
# 📡 API 호출 시작: x=127.0115252, y=37.5128516
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=잠원동
#
# 📡 API 호출 시작: x=127.0124191, y=37.57215245
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=창신동
#
# 📡 API 호출 시작: x=127.052946, y=37.62608628
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.838662, y=37.529577
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=126.903749, y=37.592443
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=신사동
#
# 📡 API 호출 시작: x=126.9866957, y=37.53898273
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=용산동2가
#
# 📡 API 호출 시작: x=127.1104622, y=37.55024867
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=광장동
#
# 📡 API 호출 시작: x=127.0960429, y=37.56219447
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=중곡동
#
# 📡 API 호출 시작: x=126.882972, y=37.481143
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=127.070461, y=37.578696
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=장안동
#
# 📡 API 호출 시작: x=127.05038, y=37.627217
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.9192838, y=37.46411007
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.08406, y=37.511957
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=잠실동
#
# 📡 API 호출 시작: x=126.8374185, y=37.5084115
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=127.1096038, y=37.33571091
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=구미동
#
# 📡 API 호출 시작: x=126.9511923, y=37.53450034
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=산천동
#
# 📡 API 호출 시작: x=127.035902, y=37.48261
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=양재동
#
# 📡 API 호출 시작: x=127.0257426, y=37.50179584
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.068237, y=37.486497
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.9117408, y=37.64594883
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=지축동
#
# 📡 API 호출 시작: x=127.139031, y=37.507604
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=방이동
#
# 📡 API 호출 시작: x=127.057883, y=37.475732
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.942914, y=37.49592954
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.867631, y=37.49008479
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=철산동
#
# 📡 API 호출 시작: x=126.9947285, y=37.56123759
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=필동2가
#
# 📡 API 호출 시작: x=126.9373154, y=37.55182728
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=신수동
#
# 📡 API 호출 시작: x=127.146938, y=37.484588
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=거여동
#
# 📡 API 호출 시작: x=126.8866227, y=37.58361875
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.963789, y=37.500751
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=흑석동
#
# 📡 API 호출 시작: x=127.143927, y=37.492387
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=거여동
#
# 📡 API 호출 시작: x=126.8372663, y=37.62994711
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=행신동
#
# 📡 API 호출 시작: x=127.1152788, y=37.74294257
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=고산동
#
# 📡 API 호출 시작: x=127.0347687, y=37.64881742
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=127.0267482, y=37.74288741
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=가능동
#
# 📡 API 호출 시작: x=126.4530635, y=37.44914222
# ✅ 처리 완료. 결과: 시=인천광역시, 구=중구, 동=운서동
#
# 📡 API 호출 시작: x=127.039655, y=37.468707
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=양재동
#
# 📡 API 호출 시작: x=127.028538, y=37.495848
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.010945, y=37.586412
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=삼선동3가
#
# 📡 API 호출 시작: x=126.880367, y=37.489291
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.916049, y=37.502859
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=126.961069, y=37.557353
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=아현동
#
# 📡 API 호출 시작: x=127.1035703, y=37.82383116
# ✅ 처리 완료. 결과: 시=경기도, 구=양주시, 동=율정동
#
# 📡 API 호출 시작: x=126.919017, y=37.631088
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=127.0871709, y=37.56144173
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=중곡동
#
# 📡 API 호출 시작: x=126.892421, y=37.566661
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.164756, y=37.565946
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=고덕동
#
# 📡 API 호출 시작: x=126.916113, y=37.449201
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.068697, y=37.48373
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.9504448, y=37.40914012
# ✅ 처리 완료. 결과: 시=경기도, 구=안양시 동안구, 동=비산동
#
# 📡 API 호출 시작: x=127.0739702, y=37.66136395
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.983392, y=37.568572
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=삼각동
#
# 📡 API 호출 시작: x=127.070593, y=37.490243
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.8684409, y=37.57911173
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=덕은동
#
# 📡 API 호출 시작: x=127.0887425, y=37.40547306
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=금토동
#
# 📡 API 호출 시작: x=126.8434492, y=37.65273224
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=성사동
#
# 📡 API 호출 시작: x=126.770226, y=37.60167786
# ✅ 처리 완료. 결과: 시=경기도, 구=김포시, 동=고촌읍
#
# 📡 API 호출 시작: x=126.889762, y=37.571242
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.0454768, y=37.77503487
# ✅ 처리 완료. 결과: 시=경기도, 구=양주시, 동=남방동
#
# 📡 API 호출 시작: x=127.089035, y=37.503906
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=삼전동
#
# 📡 API 호출 시작: x=127.0114648, y=37.51300424
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=잠원동
#
# 📡 API 호출 시작: x=126.9652008, y=37.60498061
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=평창동
#
# 📡 API 호출 시작: x=126.8393407, y=37.52999299
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=127.0134, y=37.661095
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=126.9932227, y=37.59030953
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=명륜3가
#
# 📡 API 호출 시작: x=126.985816, y=37.577387
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=재동
#
# 📡 API 호출 시작: x=126.99787, y=37.577572
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=연건동
#
# 📡 API 호출 시작: x=126.8834469, y=37.58996113
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=수색동
#
# 📡 API 호출 시작: x=127.0066567, y=37.53309011
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=한남동
#
# 📡 API 호출 시작: x=127.0196278, y=37.54821898
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=금호동4가
#
# 📡 API 호출 시작: x=126.935504, y=37.49461192
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=126.930688, y=37.577128
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=연희동
#
# 📡 API 호출 시작: x=127.0074386, y=37.63820046
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=126.9308803, y=37.57842123
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.916577, y=37.498569
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=신길동
#
# 📡 API 호출 시작: x=126.889228, y=37.573822
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.7243158, y=37.69493253
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=가좌동
#
# 📡 API 호출 시작: x=126.936862, y=37.55448
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=노고산동
#
# 📡 API 호출 시작: x=126.8992212, y=37.56033787
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=망원동
#
# 📡 API 호출 시작: x=126.9210303, y=37.55579133
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=동교동
#
# 📡 API 호출 시작: x=127.01135, y=37.627719
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.0694876, y=37.63685375
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=하계동
#
# 📡 API 호출 시작: x=127.0689347, y=37.63934286
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=중계동
#
# 📡 API 호출 시작: x=126.888568, y=37.487735
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.0139522, y=37.6337259
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=126.9231009, y=37.56090911
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=연남동
#
# 📡 API 호출 시작: x=126.889783, y=37.502477
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.9460172, y=37.56835402
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=대신동
#
# 📡 API 호출 시작: x=126.912037, y=37.583448
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=126.944763, y=37.598258
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=127.0152814, y=37.61746839
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=126.835613, y=37.506761
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=126.913138, y=37.58204
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=126.7240943, y=37.60632553
# ✅ 처리 완료. 결과: 시=경기도, 구=김포시, 동=풍무동
#
# 📡 API 호출 시작: x=126.946823, y=37.48419
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.9936746, y=37.58742039
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=명륜3가
#
# 📡 API 호출 시작: x=126.9939999, y=37.48677625
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=126.8857407, y=37.4162533
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=일직동
#
# 📡 API 호출 시작: x=127.1335237, y=37.37733474
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=서현동
#
# 📡 API 호출 시작: x=127.06898, y=37.66283
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.9261439, y=37.3322126
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=부곡동
#
# 📡 API 호출 시작: x=126.8676343, y=37.48730643
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=철산동
#
# 📡 API 호출 시작: x=126.884006, y=37.47882
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=126.9739818, y=37.57893039
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=세종로
#
# 📡 API 호출 시작: x=126.8623394, y=37.49709674
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=고척동
#
# 📡 API 호출 시작: x=126.965822, y=37.528869
# ✅ 처리 완료. 결과: 시=서울특별시, 구=용산구, 동=한강로3가
#
# 📡 API 호출 시작: x=126.8540164, y=37.48616087
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=127.070695, y=37.658467
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.889449, y=37.505305
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.0507511, y=37.47192069
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=양재동
#
# 📡 API 호출 시작: x=127.0293968, y=37.49871237
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=역삼동
#
# 📡 API 호출 시작: x=126.9036272, y=37.44016703
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=127.013424, y=37.660809
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=우이동
#
# 📡 API 호출 시작: x=127.0653703, y=37.61389253
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=석관동
#
# 📡 API 호출 시작: x=126.8751414, y=37.54833031
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=염창동
#
# 📡 API 호출 시작: x=126.8369598, y=37.5742938
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=마곡동
#
# 📡 API 호출 시작: x=126.7519145, y=37.68544489
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=대화동
#
# 📡 API 호출 시작: x=126.8575558, y=37.53362667
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=126.8826124, y=37.58343101
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=127.133178, y=37.478458
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=126.9721846, y=37.48865193
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.9738758, y=37.48392602
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.974121, y=37.49084746
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=126.8853096, y=37.51642062
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=문래동5가
#
# 📡 API 호출 시작: x=127.0863248, y=37.57863428
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=126.9278709, y=37.50206774
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=대방동
#
# 📡 API 호출 시작: x=126.854138, y=37.5129
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=127.109178, y=37.34464988
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=구미동
#
# 📡 API 호출 시작: x=126.8123587, y=37.57691187
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=방화동
#
# 📡 API 호출 시작: x=127.0671119, y=37.61510571
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=석관동
#
# 📡 API 호출 시작: x=126.8844436, y=37.51069733
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=신도림동
#
# 📡 API 호출 시작: x=126.905843, y=37.592284
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=신사동
#
# 📡 API 호출 시작: x=126.9188889, y=37.46273678
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.80181, y=37.588697
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=개화동
#
# 📡 API 호출 시작: x=127.039033, y=37.632253
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=127.0556204, y=37.52662455
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=청담동
#
# 📡 API 호출 시작: x=126.828913, y=37.513244
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=126.9125104, y=37.5827921
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=126.8378394, y=37.53096322
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강서구, 동=화곡동
#
# 📡 API 호출 시작: x=127.0422166, y=37.61580872
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=126.895203, y=37.503352
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=대림동
#
# 📡 API 호출 시작: x=126.907201, y=37.462674
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.936114, y=37.580977
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=126.9592915, y=37.564363
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=충정로3가
#
# 📡 API 호출 시작: x=126.8697333, y=37.63275411
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=도내동
#
# 📡 API 호출 시작: x=127.1112255, y=37.33788553
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=구미동
#
# 📡 API 호출 시작: x=126.8913397, y=37.54154486
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=양평동6가
#
# 📡 API 호출 시작: x=126.8987625, y=37.52959661
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=당산동4가
#
# 📡 API 호출 시작: x=127.1334, y=37.480972
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동
#
# 📡 API 호출 시작: x=126.9420277, y=37.47057382
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.042175, y=37.45851
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=원지동
#
# 📡 API 호출 시작: x=127.050328, y=37.654932
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=126.8841995, y=37.58192392
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.7661749, y=37.69404242
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=126.9114609, y=37.58029965
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=북가좌동
#
# 📡 API 호출 시작: x=127.1228896, y=37.19043691
# ✅ 처리 완료. 결과: 시=경기도, 구=화성시, 동=목동
#
# 📡 API 호출 시작: x=126.830539, y=37.514504
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=127.1662064, y=37.35150277
# ✅ 처리 완료. 결과: 시=경기도, 구=광주시, 동=능평동
#
# 📡 API 호출 시작: x=127.0182061, y=37.619902
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=미아동
#
# 📡 API 호출 시작: x=126.95927, y=37.497718
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=상도동
#
# 📡 API 호출 시작: x=127.0089069, y=37.6151911
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.0274841, y=37.66137047
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=방학동
#
# 📡 API 호출 시작: x=126.754031, y=37.48778716
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.057488, y=37.536623
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=성수동2가
#
# 📡 API 호출 시작: x=126.7651087, y=37.68613646
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=일산동
#
# 📡 API 호출 시작: x=127.109838, y=37.612494
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=신내동
#
# 📡 API 호출 시작: x=126.8882725, y=37.45760703
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=독산동
#
# 📡 API 호출 시작: x=126.8986162, y=37.45118514
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.907784, y=37.462329
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.874804, y=37.493264
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.0057137, y=37.57112723
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=종로5가
#
# 📡 API 호출 시작: x=127.0168336, y=37.4577875
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=우면동
#
# 📡 API 호출 시작: x=127.09687, y=37.589193
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.0227162, y=37.45798656
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=우면동
#
# 📡 API 호출 시작: x=127.031647, y=37.636998
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=번동
#
# 📡 API 호출 시작: x=126.827617, y=37.539253
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신월동
#
# 📡 API 호출 시작: x=126.894568, y=37.507695
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=대림동
#
# 📡 API 호출 시작: x=127.0079439, y=37.64621004
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=126.871381, y=37.546175
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=목동
#
# 📡 API 호출 시작: x=127.0143056, y=37.48474445
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.0132276, y=37.54088675
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=옥수동
#
# 📡 API 호출 시작: x=126.9303002, y=37.51810879
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=여의도동
#
# 📡 API 호출 시작: x=126.9272111, y=37.518817
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=여의도동
#
# 📡 API 호출 시작: x=126.963156, y=37.4886828
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동작구, 동=사당동
#
# 📡 API 호출 시작: x=127.0721955, y=37.51110665
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=잠실동
#
# 📡 API 호출 시작: x=126.842139, y=37.508781
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# 📡 API 호출 시작: x=126.8479791, y=37.50786172
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=고척동
#
# 📡 API 호출 시작: x=126.899382, y=37.55611
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=망원동
#
# 📡 API 호출 시작: x=126.8892689, y=37.51685884
# ✅ 처리 완료. 결과: 시=서울특별시, 구=영등포구, 동=문래동4가
#
# 📡 API 호출 시작: x=127.173781, y=37.557258
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=126.8743435, y=37.45920715
# ✅ 처리 완료. 결과: 시=경기도, 구=광명시, 동=하안동
#
# 📡 API 호출 시작: x=127.0169521, y=37.48197951
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=서초동
#
# 📡 API 호출 시작: x=127.065604, y=37.512568
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=삼성동
#
# 📡 API 호출 시작: x=126.968902, y=37.555848
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중구, 동=만리동1가
#
# 📡 API 호출 시작: x=127.057772, y=37.477328
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강남구, 동=개포동
#
# 📡 API 호출 시작: x=126.9138271, y=37.64359431
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=진관동
#
# 📡 API 호출 시작: x=126.9149514, y=37.55058599
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=서교동
#
# 📡 API 호출 시작: x=126.9048105, y=37.64741663
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 덕양구, 동=동산동
#
# 📡 API 호출 시작: x=127.0797293, y=37.56974605
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=중곡동
#
# 📡 API 호출 시작: x=127.0381737, y=37.65455985
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=쌍문동
#
# 📡 API 호출 시작: x=126.8943735, y=37.49350098
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=126.994644, y=37.610809
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.1536993, y=37.59384324
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.1704714, y=37.56115952
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=고덕동
#
# 📡 API 호출 시작: x=126.922572, y=37.459082
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.013002, y=37.62921339
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강북구, 동=수유동
#
# 📡 API 호출 시작: x=127.175519, y=37.563881
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=강일동
#
# 📡 API 호출 시작: x=127.0628214, y=37.6607334
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.92762, y=37.49044
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=126.9242273, y=37.47572798
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.879248, y=37.566485
# ✅ 처리 완료. 결과: 시=서울특별시, 구=마포구, 동=상암동
#
# 📡 API 호출 시작: x=126.9858169, y=37.49507652
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서초구, 동=방배동
#
# 📡 API 호출 시작: x=126.9071878, y=37.47676599
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=독산동
#
# 📡 API 호출 시작: x=126.748066, y=37.48985738
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9554673, y=37.49071575
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=127.009856, y=37.45581621
# ✅ 처리 완료. 결과: 시=경기도, 구=과천시, 동=과천동
#
# 📡 API 호출 시작: x=126.933025, y=37.470005
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.0503746, y=37.62321836
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=장위동
#
# 📡 API 호출 시작: x=127.0574775, y=37.62846246
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.911122, y=37.471416
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=126.9418504, y=37.49078823
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=봉천동
#
# 📡 API 호출 시작: x=127.0590506, y=37.63373538
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=127.0521635, y=37.63310967
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=127.0549268, y=37.53755207
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성동구, 동=성수동2가
#
# 📡 API 호출 시작: x=126.9079435, y=37.45099182
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=시흥동
#
# 📡 API 호출 시작: x=126.956141, y=37.596795
# ✅ 처리 완료. 결과: 시=서울특별시, 구=서대문구, 동=홍은동
#
# 📡 API 호출 시작: x=127.0819108, y=37.64615845
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=중계동
#
# 📡 API 호출 시작: x=127.15679, y=37.491832
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=127.1442444, y=37.49967595
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=127.00634, y=37.619058
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=126.7883863, y=37.71420628
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=성석동
#
# 📡 API 호출 시작: x=127.0810661, y=37.57164464
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.007624, y=37.605854
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.0719536, y=37.57732381
# ✅ 처리 완료. 결과: 시=서울특별시, 구=동대문구, 동=장안동
#
# 📡 API 호출 시작: x=126.894103, y=37.583047
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=수색동
#
# 📡 API 호출 시작: x=127.0658231, y=37.62646547
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=월계동
#
# 📡 API 호출 시작: x=126.919765, y=37.4653
# ✅ 처리 완료. 결과: 시=서울특별시, 구=관악구, 동=신림동
#
# 📡 API 호출 시작: x=127.013025, y=37.613128
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=정릉동
#
# 📡 API 호출 시작: x=127.15409, y=37.492178
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=마천동
#
# 📡 API 호출 시작: x=126.9636435, y=37.59559351
# ✅ 처리 완료. 결과: 시=서울특별시, 구=종로구, 동=부암동
#
# 📡 API 호출 시작: x=126.8557099, y=37.49165158
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=개봉동
#
# 📡 API 호출 시작: x=127.0807387, y=37.53153084
# ✅ 처리 완료. 결과: 시=서울특별시, 구=광진구, 동=자양동
#
# 📡 API 호출 시작: x=127.134153, y=37.505033
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=오금동
#
# 📡 API 호출 시작: x=126.8840903, y=37.58958074
# ✅ 처리 완료. 결과: 시=서울특별시, 구=은평구, 동=수색동
#
# 📡 API 호출 시작: x=127.080593, y=37.66967
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=상계동
#
# 📡 API 호출 시작: x=126.842363, y=37.510935
# ✅ 처리 완료. 결과: 시=서울특별시, 구=양천구, 동=신정동
#
# ...
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=127.087857, y=37.59288
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.105557, y=37.619875
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=신내동
#
# 📡 API 호출 시작: x=127.1716234, y=37.43356184
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=126.7935768, y=37.52020289
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=127.09521, y=37.73662522
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9345024, y=37.37124505
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.764352, y=37.49288282
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=중동
#
# 📡 API 호출 시작: x=126.7855326, y=37.70922862
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=성석동
#
# 📡 API 호출 시작: x=126.9430127, y=37.34755092
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=126.7894244, y=37.52020602
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=126.7981908, y=37.50983813
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 오정구, 동=여월동
#
# 📡 API 호출 시작: x=127.156515, y=37.56044925
# ✅ 처리 완료. 결과: 시=서울특별시, 구=강동구, 동=고덕동
#
# 📡 API 호출 시작: x=127.0795439, y=37.73359912
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=용현동
#
# 📡 API 호출 시작: x=127.0899025, y=37.59336525
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1280966, y=37.39668878
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=이매동
#
# 📡 API 호출 시작: x=127.1736286, y=37.43432286
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1485717, y=37.59090749
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.096144, y=37.73922778
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9331138, y=37.37010437
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.7615756, y=37.49331346
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=중동
#
# 📡 API 호출 시작: x=126.7886365, y=37.71396345
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=성석동
#
# 📡 API 호출 시작: x=126.7973991, y=37.5063732
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 오정구, 동=여월동
#
# 📡 API 호출 시작: x=127.0833262, y=37.73126002
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=용현동
#
# 📡 API 호출 시작: x=126.7649158, y=37.69506069
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=127.1763357, y=37.43430397
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1462272, y=37.5912801
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=126.7864856, y=37.51959308
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 오정구, 동=내동
#
# 📡 API 호출 시작: x=127.1280725, y=37.3929675
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=이매동
#
# 📡 API 호출 시작: x=127.0960268, y=37.7401256
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9307792, y=37.36809828
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.759962, y=37.49352272
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.7906122, y=37.71616306
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=성석동
#
# 📡 API 호출 시작: x=126.777822, y=37.68548786
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=일산동
#
# 📡 API 호출 시작: x=126.9421294, y=37.34657123
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=126.7566697, y=37.49395747
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.7941698, y=37.50509529
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=춘의동
#
# 📡 API 호출 시작: x=126.9397271, y=37.34402261
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=127.1671507, y=37.43320936
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.0549536, y=37.64503448
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=126.9368458, y=37.36863176
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.9578224, y=37.36868618
# ✅ 처리 완료. 결과: 시=경기도, 구=안양시 동안구, 동=호계동
#
# 📡 API 호출 시작: x=127.1790171, y=37.43507339
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1429597, y=37.59180109
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.0971935, y=37.74212581
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9291886, y=37.36671862
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.778843, y=37.68724238
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=중산동
#
# 📡 API 호출 시작: x=126.7845661, y=37.51783824
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=127.053492, y=37.652111
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=126.9580535, y=37.36612773
# ✅ 처리 완료. 결과: 시=경기도, 구=안양시 동안구, 동=호계동
#
# 📡 API 호출 시작: x=126.780719, y=37.68894718
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=중산동
#
# 📡 API 호출 시작: x=127.1402313, y=37.59220973
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=126.9333783, y=37.36385862
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.9265151, y=37.36448218
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.7631888, y=37.69931578
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=126.7545244, y=37.49291675
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9383386, y=37.34223158
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=127.0995604, y=37.7454595
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.7845658, y=37.51566338
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=126.7903247, y=37.50441796
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=춘의동
#
# 📡 API 호출 시작: x=127.1791804, y=37.43547482
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1690676, y=37.43435949
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=상대원동
#
# 📡 API 호출 시작: x=127.1001605, y=37.74877652
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=126.7596001, y=37.69531383
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=덕이동
#
# 📡 API 호출 시작: x=127.1378594, y=37.59079487
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=교문동
#
# 📡 API 호출 시작: x=126.7845455, y=37.51092662
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=126.7804557, y=37.69079661
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=중산동
#
# 📡 API 호출 시작: x=126.9597525, y=37.36340824
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당정동
#
# 📡 API 호출 시작: x=126.9331007, y=37.36032302
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.9239545, y=37.36232687
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.7517569, y=37.48871518
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9374371, y=37.33986179
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=126.7862046, y=37.50023732
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=춘의동
#
# 📡 API 호출 시작: x=126.7790376, y=37.69372815
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산동구, 동=중산동
#
# 📡 API 호출 시작: x=127.1019774, y=37.7504267
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=126.7591829, y=37.6887219
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=덕이동
#
# 📡 API 호출 시작: x=127.0925625, y=37.74087058
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=127.1378311, y=37.58875936
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=교문동
#
# 📡 API 호출 시작: x=127.1450171, y=37.43878981
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=성남동
#
# 📡 API 호출 시작: x=126.7853109, y=37.50821739
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=도당동
#
# 📡 API 호출 시작: x=126.9627324, y=37.36081115
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=오전동
#
# 📡 API 호출 시작: x=126.9343207, y=37.3355858
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=부곡동
#
# 📡 API 호출 시작: x=126.9229398, y=37.3611187
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.7473831, y=37.48902127
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.7855808, y=37.4975001
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.0918263, y=37.74332594
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=127.1391978, y=37.58749256
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.1442938, y=37.43793424
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=성남동
#
# 📡 API 호출 시작: x=126.7866278, y=37.50464048
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=춘의동
#
# 📡 API 호출 시작: x=126.9661596, y=37.35772017
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=오전동
#
# 📡 API 호출 시작: x=126.9292216, y=37.33371237
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=부곡동
#
# 📡 API 호출 시작: x=126.9235972, y=37.3585059
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.7848142, y=37.49412341
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.1040942, y=37.75204354
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=127.0935931, y=37.74610957
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.8936972, y=37.48273209
# ✅ 처리 완료. 결과: 시=서울특별시, 구=구로구, 동=구로동
#
# 📡 API 호출 시작: x=127.053249, y=37.65173
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=127.1437317, y=37.58689249
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=토평동
#
# 📡 API 호출 시작: x=127.074318, y=37.58932
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1409695, y=37.43611233
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=성남동
#
# 📡 API 호출 시작: x=126.9697717, y=37.35400093
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=오전동
#
# 📡 API 호출 시작: x=127.1076113, y=37.75292697
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=126.9261075, y=37.35439843
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=126.784257, y=37.49170668
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.05452, y=37.644731
# ✅ 처리 완료. 결과: 시=서울특별시, 구=도봉구, 동=창동
#
# 📡 API 호출 시작: x=126.9283587, y=37.35159382
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=산본동
#
# 📡 API 호출 시작: x=127.1483239, y=37.58687224
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=토평동
#
# 📡 API 호출 시작: x=127.077666, y=37.59043
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.138215, y=37.43468629
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=성남동
#
# 📡 API 호출 시작: x=126.9732805, y=37.34881699
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=고천동
#
# 📡 API 호출 시작: x=127.1101115, y=37.75204354
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=126.7835576, y=37.48861625
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.0988937, y=37.74917657
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=127.1157775, y=37.35183869
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=금곡동
#
# 📡 API 호출 시작: x=127.1490998, y=37.58896465
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=토평동
#
# 📡 API 호출 시작: x=127.080896, y=37.59131195
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1363287, y=37.43095811
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=성남동
#
# 📡 API 호출 시작: x=126.9377638, y=37.34836297
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=127.1131786, y=37.75241024
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=126.7684242, y=37.6977927
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=126.9733139, y=37.34398314
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=고천동
#
# 📡 API 호출 시작: x=126.7814934, y=37.48616678
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.1585306, y=37.44769461
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=금광동
#
# 📡 API 호출 시작: x=127.083885, y=37.592028
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=126.9410909, y=37.34743073
# ✅ 처리 완료. 결과: 시=경기도, 구=군포시, 동=당동
#
# 📡 API 호출 시작: x=127.1136786, y=37.75399375
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=낙양동
#
# 📡 API 호출 시작: x=127.110553, y=37.35014287
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 분당구, 동=금곡동
#
# 📡 API 호출 시작: x=126.9706643, y=37.34154657
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=고천동
#
# 📡 API 호출 시작: x=126.7786087, y=37.48656687
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.1593582, y=37.44971576
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=금광동
#
# 📡 API 호출 시작: x=127.1393637, y=37.42919691
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=127.1542161, y=37.59347654
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=토평동
#
# 📡 API 호출 시작: x=127.081197, y=37.578455
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1428222, y=37.42787257
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=127.1163955, y=37.75477717
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.9669082, y=37.33766193
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=이동
#
# 📡 API 호출 시작: x=126.7761198, y=37.4869316
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=심곡동
#
# 📡 API 호출 시작: x=127.160154, y=37.4514474
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=금광동
#
# 📡 API 호출 시작: x=127.1597167, y=37.59322651
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.1454981, y=37.42816197
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=127.1176123, y=37.75127679
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.964313, y=37.33604896
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=이동
#
# 📡 API 호출 시작: x=127.0826783, y=37.57981406
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=126.766487, y=37.69427488
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=탄현동
#
# 📡 API 호출 시작: x=126.7718528, y=37.48757732
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=중동
#
# 📡 API 호출 시작: x=127.1617809, y=37.45467943
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=은행동
#
# 📡 API 호출 시작: x=127.156612, y=37.59355693
# ✅ 처리 완료. 결과: 시=경기도, 구=구리시, 동=수택동
#
# 📡 API 호출 시작: x=127.092532, y=37.59388
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.090082, y=37.613983
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=신내동
#
# 📡 API 호출 시작: x=127.148744, y=37.42897136
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=126.9602459, y=37.33461547
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=이동
#
# 📡 API 호출 시작: x=126.7667412, y=37.48830102
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=중동
#
# 📡 API 호출 시작: x=127.1643787, y=37.45771481
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=은행동
#
# 📡 API 호출 시작: x=127.1176456, y=37.74992665
# ✅ 처리 완료. 결과: 시=경기도, 구=의정부시, 동=민락동
#
# 📡 API 호출 시작: x=126.7477736, y=37.67950241
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=대화동
#
# 📡 API 호출 시작: x=127.0917244, y=37.61376091
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=신내동
#
# 📡 API 호출 시작: x=127.1523233, y=37.42986198
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=126.7625114, y=37.48846375
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1666651, y=37.46036766
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=은행동
#
# 📡 API 호출 시작: x=126.9564392, y=37.33159634
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=이동
#
# 📡 API 호출 시작: x=127.1680291, y=37.46141407
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=은행동
#
# 📡 API 호출 시작: x=127.1578008, y=37.43204151
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=하대원동
#
# 📡 API 호출 시작: x=126.7602225, y=37.48988283
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9576334, y=37.32414322
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=삼동
#
# 📡 API 호출 시작: x=126.7514887, y=37.69069719
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=덕이동
#
# 📡 API 호출 시작: x=127.065462, y=37.613598
# ✅ 처리 완료. 결과: 시=서울특별시, 구=성북구, 동=석관동
#
# 📡 API 호출 시작: x=127.1205626, y=37.64629886
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.8789631, y=37.48332716
# ✅ 처리 완료. 결과: 시=서울특별시, 구=금천구, 동=가산동
#
# 📡 API 호출 시작: x=126.9572772, y=37.3219425
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=삼동
#
# 📡 API 호출 시작: x=127.1693709, y=37.46243714
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 중원구, 동=은행동
#
# 📡 API 호출 시작: x=127.1698344, y=37.46389598
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=양지동
#
# 📡 API 호출 시작: x=126.7487576, y=37.69180204
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=덕이동
#
# 📡 API 호출 시작: x=127.1224461, y=37.64763235
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.9574765, y=37.31969319
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=삼동
#
# 📡 API 호출 시작: x=127.1629337, y=37.46311257
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=양지동
#
# 📡 API 호출 시작: x=127.068945, y=37.639192
# ✅ 처리 완료. 결과: 시=서울특별시, 구=노원구, 동=하계동
#
# 📡 API 호출 시작: x=126.7453752, y=37.69281757
# ✅ 처리 완료. 결과: 시=경기도, 구=고양시 일산서구, 동=덕이동
#
# 📡 API 호출 시작: x=127.1263436, y=37.65046701
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.9576623, y=37.31397993
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=126.7538304, y=37.49415881
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1261021, y=37.65297809
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=127.1558329, y=37.46249583
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=단대동
#
# 📡 API 호출 시작: x=126.757787, y=37.49118441
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9578761, y=37.31014266
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=126.749174, y=37.49423672
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1515135, y=37.45829731
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=산성동
#
# 📡 API 호출 시작: x=126.7529341, y=37.49162485
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=126.9580127, y=37.30653655
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=126.747806, y=37.49265762
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1249292, y=37.65518307
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.7498693, y=37.4916454
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1447081, y=37.46116883
# ✅ 처리 완료. 결과: 시=경기도, 구=성남시 수정구, 동=창곡동
#
# 📡 API 호출 시작: x=126.9573287, y=37.30592424
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=126.7477682, y=37.48977645
# ✅ 처리 완료. 결과: 시=경기도, 구=부천시 원미구, 동=상동
#
# 📡 API 호출 시작: x=127.1238929, y=37.65626754
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=127.1215725, y=37.65793816
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.9559466, y=37.30445144
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=127.0838864, y=37.58193312
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.0836907, y=37.58415445
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1183991, y=37.65654682
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=126.9558897, y=37.3029005
# ✅ 처리 완료. 결과: 시=경기도, 구=의왕시, 동=월암동
#
# 📡 API 호출 시작: x=127.0839472, y=37.58670525
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.1159929, y=37.65183252
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=127.085383, y=37.590405
# ✅ 처리 완료. 결과: 시=서울특별시, 구=중랑구, 동=면목동
#
# 📡 API 호출 시작: x=127.11415, y=37.64983729
# ✅ 처리 완료. 결과: 시=경기도, 구=남양주시, 동=별내동
#
# 📡 API 호출 시작: x=127.133242, y=37.478367
# ✅ 처리 완료. 결과: 시=서울특별시, 구=송파구, 동=장지동

# %%
api_cache
# Out:
# {(127.1027997, 37.61354475): {'시': '서울특별시', '구': '중랑구', '동': '신내동'},
#  (127.0407624, 37.65893642): {'시': '서울특별시', '구': '도봉구', '동': '쌍문동'},
#  (126.969153, 37.556235): {'시': '서울특별시', '구': '중구', '동': '만리동1가'},
#  (126.93783, 37.46571): {'시': '서울특별시', '구': '관악구', '동': '신림동'},
#  (126.9398176, 37.47037897): {'시': '서울특별시', '구': '관악구', '동': '신림동'},
#  (126.919247, 37.489233): {'시': '서울특별시', '구': '관악구', '동': '신림동'},
#  (127.0503112, 37.62754013): {'시': '서울특별시', '구': '노원구', '동': '월계동'},
#  (126.956215, 37.491679): {'시': '서울특별시', '구': '동작구', '동': '상도동'},
#  (126.892827, 37.490156): {'시': '서울특별시', '구': '구로구', '동': '구로동'},
#  (126.9572808, 37.49531836): {'시': '서울특별시', '구': '동작구', '동': '상도동'},
#  (126.92119, 37.453078): {'시': '서울특별시', '구': '금천구', '동': '시흥동'},
#  (127.1762683, 37.3455333): {'시': '경기도', '구': '광주시', '동': '능평동'},
#  (126.8688211, 37.49056774): {'시': '경기도', '구': '광명시', '동': '철산동'},
#  (126.8688129, 37.49065738): {'시': '경기도', '구': '광명시', '동': '철산동'},
#  (126.989289, 37.55974): {'시': '서울특별시', '구': '중구', '동': '예장동'},
#  (127.12764, 37.469822): {'시': '서울특별시', '구': '송파구', '동': '장지동'},
#  (126.9880882, 37.46569518): {'시': '서울특별시', '구': '서초구', '동': '방배동'},
#  (126.80188, 37.562495): {'시': '서울특별시', '구': '강서구', '동': '방화동'},
#  (126.96306, 37.53216): {'시': '서울특별시', '구': '용산구', '동': '한강로3가'},
    # 'a' 컬럼값이 이미 존재하는지 확인 (NaN이 아닌 경우)
    if pd.notna(row['시']):
        return row
    
    # 캐시에서 결과를 찾아서 적용
    if coord_key in api_cache:
        result = api_cache[coord_key]
        row['시'] = result.get('시', row['시'])
        row['구'] = result.get('구', row['구'])
        row['동'] = result.get('동', row['동'])
    
    return row

# %%
# 6. 데이터프레임에 결과 일괄 적용
print("\n--- 결과 일괄 적용 중 ---")

# apply 함수를 사용하여 모든 행에 결과를 적용합니다.
src_df = src_df.apply(apply_api_result, axis=1)

# 7. 최종 결과 출력
print("\n=== 최종 결과 데이터프레임 ===")
print(src_df.head())
# Out:
# --- 결과 일괄 적용 중 ---
#
# === 최종 결과 데이터프레임 ===
#     ROUTE_ID   노선명  순번    NODE_ID  ARS_ID         정류소명       X좌표        Y좌표  \
# 0  100100407   240   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 1  100100049   273   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 2  100100186  2012   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 3  100100190  2015   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
# 4  100100599  2311   1  106000319    7418  중랑공영차고지.신내역  127.1028  37.613545
#
#        시    구    동
# 0  서울특별시  중랑구  신내동
# 1  서울특별시  중랑구  신내동
# 2  서울특별시  중랑구  신내동
# 3  서울특별시  중랑구  신내동
# 4  서울특별시  중랑구  신내동

# %%
src_df
# Out:
#         ROUTE_ID   노선명   순번    NODE_ID  ARS_ID               정류소명         X좌표  \
# 0      100100407   240    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 1      100100049   273    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 2      100100186  2012    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 3      100100190  2015    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 4      100100599  2311    1  106000319    7418        중랑공영차고지.신내역  127.102800
# ...          ...   ...  ...        ...     ...                ...         ...
# 41256  100100589   N61  183  116000142   17233                개봉역  126.856720
# 41257  100100589   N61  184  116000144   17235  개봉1동사거리.개봉푸르지오아파트  126.846791
# 41258  100100589   N61  185  114000125   15228           신정학마을아파트  126.843963
# 41259  100100589   N61  186  114000257   15362    신정현대아파트.서부트럭터미널  126.842007
# 41260  100100589   N61  187  114000267   15373            양천공영차고지  126.837219
#
#              Y좌표      시    구    동
# 0      37.613545  서울특별시  중랑구  신내동
# 1      37.613545  서울특별시  중랑구  신내동
# 2      37.613545  서울특별시  중랑구  신내동
# 3      37.613545  서울특별시  중랑구  신내동
# 4      37.613545  서울특별시  중랑구  신내동
# ...          ...    ...  ...  ...
# 41256  37.493978  서울특별시  구로구  개봉동
# 41257  37.501413  서울특별시  구로구  개봉동
# 41258  37.507421  서울특별시  양천구  신정동
# 41259  37.509011  서울특별시  양천구  신정동
# 41260  37.508493  서울특별시  양천구  신정동
#
# [41261 rows x 11 columns]

# %%
src_df.to_csv('20251014_서울시_버스정류장_주소.csv', index=False, encoding='utf-8')
