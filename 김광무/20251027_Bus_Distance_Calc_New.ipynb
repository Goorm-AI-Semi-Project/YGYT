# %%
def discretize_bearing(bearing):
  """
  방위각(0~360도)을 0, 90, 180, 270도 중 가장 가까운 값으로 정제합니다.
  """
  # 북쪽 기준을 위해 22.5도를 더하고, 360도로 나눈 나머지를 취합니다.
  # 이렇게 하면 북쪽(0도)을 기준으로 22.5~67.5도는 45도 범위에 들어갑니다.
  adjusted_bearing = (bearing + 45) % 360 

  # adjusted_bearing을 90으로 나누어 몇 번째 사분면에 가까운지 확인
  # 예: 10도 -> (10+45)%360 = 55 -> 55/90 = 0.61 -> round(0.61) * 90 = 0
  # 예: 100도 -> (100+45)%360 = 145 -> 145/90 = 1.61 -> round(1.61) * 90 = 180 (X) -> 이 방법은 복잡하고 오류 가능성이 높습니다.

  # 직관적인 방법을 사용합니다.
  
  # 45도로 나누어 몫을 구합니다.
  # 0~45도: 0/90 (북)
  # 45~135도: 90/90 (동)
  # 135~225도: 180/90 (남)
  # 225~315도: 270/90 (서)
  # 315~360도: 360/90 (북)
  
  # 북쪽을 $360^\circ$로 생각하고 조정하여 반올림합니다.
  if bearing > 315 or bearing <= 45:
    return 0 # 북
  elif bearing > 45 and bearing <= 135:
    return 90 # 동
  elif bearing > 135 and bearing <= 225:
    return 180 # 남
  elif bearing > 225 and bearing <= 315:
    return 270 # 서
  else:
    # 이 부분은 발생하지 않아야 하지만, 안전을 위해 0을 반환합니다.
    return 0

# %%
# 예시 테스트:
print(f"방위각 20도 -> 정제 방향: {discretize_bearing(20)}도 (북)")
print(f"방위각 110도 -> 정제 방향: {discretize_bearing(110)}도 (동)")
print(f"방위각 200도 -> 정제 방향: {discretize_bearing(200)}도 (남)")
print(f"방위각 300도 -> 정제 방향: {discretize_bearing(300)}도 (서)")
print(f"방위각 350도 -> 정제 방향: {discretize_bearing(350)}도 (북)")
# Out:
# 방위각 20도 -> 정제 방향: 0도 (북)
# 방위각 110도 -> 정제 방향: 90도 (동)
# 방위각 200도 -> 정제 방향: 180도 (남)
# 방위각 300도 -> 정제 방향: 270도 (서)
# 방위각 350도 -> 정제 방향: 0도 (북)

# %%
import math

def calculate_bearing(lat1, lon1, lat2, lon2):
  # 1. 모든 도(Degree) 값을 라디안(Radian)으로 변환
  lat1_rad = math.radians(float(lat1))
  lon1_rad = math.radians(float(lon1))
  lat2_rad = math.radians(float(lat2))
  lon2_rad = math.radians(float(lon2))

  # 경도 차이
  dLon = lon2_rad - lon1_rad

  # 2. 방위각 계산 공식 적용 (arctan2 사용)
  y = math.sin(dLon) * math.cos(lat2_rad)
  x = math.cos(lat1_rad) * math.sin(lat2_rad) - math.sin(lat1_rad) * math.cos(lat2_rad) * math.cos(dLon)
  
  # atan2는 라디안으로 결과를 반환하며, x, y 값을 통해 사분면을 고려함
  bearing_rad = math.atan2(y, x)

  # 3. 라디안을 도(Degree)로 변환
  bearing_deg = math.degrees(bearing_rad)

  # 4. 0 ~ 360도 범위로 조정
  # 결과가 음수일 경우 360을 더해서 양수로 만듦 (예: -90 -> 270)
  final_bearing = (bearing_deg + 360) % 360

  return final_bearing

# %%
# 예시: 서울(출발지)에서 부산(도착지) 방향
seoul_lat, seoul_lon = 37.5665, 126.9780
busan_lat, busan_lon = 35.1796, 129.0756

direction = calculate_bearing(seoul_lat, seoul_lon, busan_lat, busan_lon)

print(f"서울에서 부산으로의 이동 방향 (방위각): {direction:.2f}도, 정제{discretize_bearing(direction)}") 
# 결과는 약 154.55도로, 남동쪽 (135도) 방향에 가까움을 알 수 있습니다.
# Out:
# 서울에서 부산으로의 이동 방향 (방위각): 144.09도, 정제180

# %%
def calcAngle(originX, originY, destX, destY):
    return discretize_bearing(calculate_bearing(originY, originX, destY, destX))

# %%
print("calcAngle=", calcAngle(seoul_lon, seoul_lat, busan_lon, busan_lat))
# Out:
# calcAngle= 180

# %%
import requests

# 2개스페이스로 된 탭으로 보여줍니다.
# URL 및 헤더 정보
url = "https://apis-navi.kakaomobility.com/v1/directions"
headers = {
  "Authorization": "KakaoAK 430d403638a9ccddb70657adb3ed7196"
}

originX = "127.1027997"
originY = "37.61354475"
destX = "127.099763"
destY = "37.614242"

# 쿼리 파라미터 (Query Parameters)
# curl 명령어의 '?' 뒤에 오는 부분입니다.
params = {
  "origin": f"{originX},{originY},angle={calcAngle(originX, originY, destX, destY)}",
  "destination": f"{destX},{destY}",
  "priority": "DISTANCE", # DISTANCE:최단거리, TIME:최단시간, RECOMMEND:추천
  "car_type": "3", # 1:소형,2:중형,3:대형(33인승이상)
  "summary":"true" #요약정보만
}

try:
  # GET 요청 보내기
  response = requests.get(url, headers=headers, params=params)

  # 응답 확인
  if response.status_code == 200:
    # 성공 시 JSON 응답 출력
    print("요청 성공 (Status Code: 200)")
    # print(response.json()) # 전체 JSON 응답을 보고 싶을 때
    
    # 예시로 응답의 주요 정보만 출력
    data = response.json()
    if 'routes' in data and data['routes']:
      print(f"경로 수: {len(data['routes'])}개")
      first_route = data['routes'][0]['summary']
      print(f"총 거리: {first_route['distance']} m")
      print(f"총 시간: {first_route['duration']} 초")
    else:
      print("경로 데이터가 응답에 포함되어 있지 않습니다.")
    
  else:
    # 오류 발생 시 상태 코드 및 내용 출력
    print(f"요청 실패 (Status Code: {response.status_code})")
    print(f"오류 메시지: {response.text}")

except requests.exceptions.RequestException as e:
  # 네트워크 등 요청 자체의 오류 처리
  print(f"요청 중 오류 발생: {e}")
# Out:
# 요청 성공 (Status Code: 200)
# 경로 수: 1개
# 총 거리: 278 m
# 총 시간: 80 초

# %%
import pandas as pd
import numpy as np

src_df = pd.read_csv('20251014_서울시_버스정류장_주소.csv')

# %%
src_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41261 entries, 0 to 41260
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ROUTE_ID  41261 non-null  int64
#  1   노선명       41261 non-null  object
#  2   순번        41261 non-null  int64
#  3   NODE_ID   41261 non-null  int64
#  4   ARS_ID    41261 non-null  int64
#  5   정류소명      41261 non-null  object
#  6   X좌표       41261 non-null  float64
#  7   Y좌표       41261 non-null  float64
#  8   시         41261 non-null  object
#  9   구         41261 non-null  object
#  10  동         41261 non-null  object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 3.5+ MB

# %%
src_df['거리'] = 0

# %%
src_df
# Out:
#         ROUTE_ID   노선명   순번    NODE_ID  ARS_ID               정류소명         X좌표  \
# 0      100100407   240    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 1      100100049   273    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 2      100100186  2012    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 3      100100190  2015    1  106000319    7418        중랑공영차고지.신내역  127.102800
# 4      100100599  2311    1  106000319    7418        중랑공영차고지.신내역  127.102800
# ...          ...   ...  ...        ...     ...                ...         ...
# 41256  100100589   N61  183  116000142   17233                개봉역  126.856720
# 41257  100100589   N61  184  116000144   17235  개봉1동사거리.개봉푸르지오아파트  126.846791
# 41258  100100589   N61  185  114000125   15228           신정학마을아파트  126.843963
# 41259  100100589   N61  186  114000257   15362    신정현대아파트.서부트럭터미널  126.842007
# 41260  100100589   N61  187  114000267   15373            양천공영차고지  126.837219
#
#              Y좌표      시    구    동  거리
# 0      37.613545  서울특별시  중랑구  신내동   0
# 1      37.613545  서울특별시  중랑구  신내동   0
# 2      37.613545  서울특별시  중랑구  신내동   0
# 3      37.613545  서울특별시  중랑구  신내동   0
# 4      37.613545  서울특별시  중랑구  신내동   0
# ...          ...    ...  ...  ...  ..
# 41256  37.493978  서울특별시  구로구  개봉동   0
# 41257  37.501413  서울특별시  구로구  개봉동   0
# 41258  37.507421  서울특별시  양천구  신정동   0
# 41259  37.509011  서울특별시  양천구  신정동   0
# 41260  37.508493  서울특별시  양천구  신정동   0
#
# [41261 rows x 12 columns]

# %%
import pandas as pd
import requests
import time
import json
from io import StringIO
from math import isnan # NaN 값 비교를 위해 임포트

# %%
grouped = src_df.groupby('노선명')

# %%
print(len(grouped))
# Out:
# 705

# %%
# grouped 객체의 반복자에서 첫 번째 요소를 가져옵니다.
first_element = next(iter(grouped))

# first_element는 (그룹 이름, 그룹 DataFrame) 형태의 튜플입니다.
# 이를 두 변수로 나누어 받을 수 있습니다.
group_name, group_df = first_element

# 첫 번째 그룹 이름 출력
print(f"첫 번째 그룹 이름: {group_name}")

# 첫 번째 그룹의 데이터프레임 출력
print("--- 첫 번째 그룹 데이터프레임 ---")
print(group_df)
# Out:
# 첫 번째 그룹 이름: 0017
# --- 첫 번째 그룹 데이터프레임 ---
#         ROUTE_ID   노선명  순번    NODE_ID  ARS_ID             정류소명         X좌표  \
# 720    100100124  0017   2  102000158    3252          신용산지하차도  126.963882
# 1663   100100124  0017   3  102000161    3255              용산역  126.965822
# 2683   100100124  0017   4  102000162    3256         용산푸르지오써밋  126.964759
# 3254   100100124  0017   5  102000029    3122           한강대교북단  126.963570
# 3534   100100124  0017   6  102000200    3294          서부이촌동입구  126.959497
# 4655   100100124  0017   7  102000198    3292  이촌2동대림아파트.새남터성지  126.956323
# 5258   100100124  0017   8  102000196    3290         이촌2동주민센터  126.955064
# 5945   100100124  0017   9  102000194    3288     성촌공원.포르쉐센터용산  126.954606
# 6671   100100124  0017  10  102000193    3287   이촌119안전센터.성촌공원  126.952943
# 7337   100100124  0017  11  102000202    3296      원효2동산호아파트후문  126.950016
# 7787   100100124  0017  12  102000204    3298       청암동강변삼성아파트  126.949323
# 8671   100100124  0017  13  102000227    3321            청심경로당  126.950688
# 9434   100100124  0017  14  102000210    3304         원효2동주민센터  126.951395
# 9984   100100124  0017  15  102000212    3306      산천동.성심여중고후문  126.953643
# 10626  100100124  0017  16  102000214    3308         신창동세방아파트  126.954955
# 11377  100100124  0017  17  102000216    3310           남이장군사당  126.957822
# 12009  100100124  0017  18  102000218    3312    용문시장.용문동새마을금고  126.959534
# 12296  100100124  0017  19  102000153    3247             용문시장  126.960969
# 13245  100100124  0017  20  102000156    3250         용산전자상가입구  126.961938
# 13864  100100124  0017  21  102000158    3252          신용산지하차도  126.963882
# 14351  100100124  0017  22  102000026    3119         신용산역3번출구  126.967351
# 14742  100100124  0017  23  102000157    3251          신용산지하차도  126.963668
# 15618  100100124  0017  24  102000155    3249         용산전자상가입구  126.962222
# 15934  100100124  0017  25  102000154    3248             용문시장  126.961360
# 16751  100100124  0017  26  102000219    3313    용문시장.용문동새마을금고  126.959197
# 17281  100100124  0017  27  102000217    3311           남이장군사당  126.957703
# 17643  100100124  0017  28  102000215    3309         신창동세방아파트  126.954947
# 18436  100100124  0017  29  102000213    3307      산천동.성심여중고후문  126.953382
# 18950  100100124  0017  30  102000211    3305      산천동리버힐삼성아파트  126.951192
# 19439  100100124  0017  31  102000228    3322            삼성테마트  126.950385
# 19685  100100124  0017  32  102000205    3299        원효2동산호아파트  126.950542
# 20198  100100124  0017  33  102000207    3301         원효로풍전아파트  126.953523
# 21082  100100124  0017  34  102000195    3289     성촌공원.포르쉐센터용산  126.954351
# 21362  100100124  0017  35  102000197    3291         이촌2동주민센터  126.954862
# 21813  100100124  0017  36  102000199    3293  이촌2동대림아파트.새남터성지  126.956166
# 22090  100100124  0017  37  102000201    3295        이촌2동강변아파트  126.959781
# 22670  100100124  0017  38  102000001    3001    한강대교북단.LG유플러스  126.963121
# 22940  100100124  0017  39  102000003    3003             신용산역  126.966207
# 23540  100100124  0017  40  102000159    3253         신용산역5번출구  126.967679
# 24113  100100124  0017  41  102000318    3121    용산역3번출구.용산차고지  126.964215
#
#              Y좌표      시    구      동  거리
# 720    37.532590  서울특별시  용산구  한강로3가   0
# 1663   37.528869  서울특별시  용산구  한강로3가   0
# 2683   37.527574  서울특별시  용산구  한강로3가   0
# 3254   37.524968  서울특별시  용산구  한강로3가   0
# 3534   37.523863  서울특별시  용산구  한강로3가   0
# 4655   37.526175  서울특별시  용산구    이촌동   0
# 5258   37.527736  서울특별시  용산구  한강로3가   0
# 5945   37.530171  서울특별시  용산구  한강로3가   0
# 6671   37.530082  서울특별시  용산구    이촌동   0
# 7337   37.532260  서울특별시  용산구  원효로4가   0
# 7787   37.534015  서울특별시  용산구  원효로4가   0
# 8671   37.533887  서울특별시  용산구    산천동   0
# 9434   37.534494  서울특별시  용산구    산천동   0
# 9984   37.535320  서울특별시  용산구    신창동   0
# 10626  37.535708  서울특별시  용산구    신창동   0
# 11377  37.536608  서울특별시  용산구    용문동   0
# 12009  37.537072  서울특별시  용산구    용문동   0
# 12296  37.536348  서울특별시  용산구    용문동   0
# 13245  37.534658  서울특별시  용산구  원효로2가   0
# 13864  37.532590  서울특별시  용산구  한강로3가   0
# 14351  37.528889  서울특별시  용산구  한강로2가   0
# 14742  37.532835  서울특별시  용산구  한강로3가   0
# 15618  37.534570  서울특별시  용산구    신계동   0
# 15934  37.535979  서울특별시  용산구  원효로2가   0
# 16751  37.537149  서울특별시  용산구    용문동   0
# 17281  37.536824  서울특별시  용산구    용문동   0
# 17643  37.535830  서울특별시  용산구    신창동   0
# 18436  37.535408  서울특별시  용산구    신창동   0
# 18950  37.534500  서울특별시  용산구    산천동   0
# 19439  37.533747  서울특별시  용산구  원효로4가   0
# 19685  37.533018  서울특별시  용산구  원효로4가   0
# 20198  37.532129  서울특별시  용산구  원효로4가   0
# 21082  37.529747  서울특별시  용산구    이촌동   0
# 21362  37.527703  서울특별시  용산구    이촌동   0
# 21813  37.526029  서울특별시  용산구    이촌동   0
# 22090  37.523446  서울특별시  용산구    이촌동   0
# 22670  37.524049  서울특별시  용산구  한강로3가   0
# 22940  37.527293  서울특별시  용산구  한강로2가   0
# 23540  37.530034  서울특별시  용산구  한강로2가   0
# 24113  37.531808  서울특별시  용산구  한강로3가   0

# %%
route_each_df = src_df[src_df['노선명'] == '0017'].copy()
route_each_df
# Out:
#         ROUTE_ID   노선명  순번    NODE_ID  ARS_ID             정류소명         X좌표  \
# 720    100100124  0017   2  102000158    3252          신용산지하차도  126.963882
# 1663   100100124  0017   3  102000161    3255              용산역  126.965822
# 2683   100100124  0017   4  102000162    3256         용산푸르지오써밋  126.964759
# 3254   100100124  0017   5  102000029    3122           한강대교북단  126.963570
# 3534   100100124  0017   6  102000200    3294          서부이촌동입구  126.959497
# 4655   100100124  0017   7  102000198    3292  이촌2동대림아파트.새남터성지  126.956323
# 5258   100100124  0017   8  102000196    3290         이촌2동주민센터  126.955064
# 5945   100100124  0017   9  102000194    3288     성촌공원.포르쉐센터용산  126.954606
# 6671   100100124  0017  10  102000193    3287   이촌119안전센터.성촌공원  126.952943
# 7337   100100124  0017  11  102000202    3296      원효2동산호아파트후문  126.950016
# 7787   100100124  0017  12  102000204    3298       청암동강변삼성아파트  126.949323
# 8671   100100124  0017  13  102000227    3321            청심경로당  126.950688
# 9434   100100124  0017  14  102000210    3304         원효2동주민센터  126.951395
# 9984   100100124  0017  15  102000212    3306      산천동.성심여중고후문  126.953643
# 10626  100100124  0017  16  102000214    3308         신창동세방아파트  126.954955
# 11377  100100124  0017  17  102000216    3310           남이장군사당  126.957822
# 12009  100100124  0017  18  102000218    3312    용문시장.용문동새마을금고  126.959534
# 12296  100100124  0017  19  102000153    3247             용문시장  126.960969
# 13245  100100124  0017  20  102000156    3250         용산전자상가입구  126.961938
# 13864  100100124  0017  21  102000158    3252          신용산지하차도  126.963882
# 14351  100100124  0017  22  102000026    3119         신용산역3번출구  126.967351
# 14742  100100124  0017  23  102000157    3251          신용산지하차도  126.963668
# 15618  100100124  0017  24  102000155    3249         용산전자상가입구  126.962222
# 15934  100100124  0017  25  102000154    3248             용문시장  126.961360
# 16751  100100124  0017  26  102000219    3313    용문시장.용문동새마을금고  126.959197
# 17281  100100124  0017  27  102000217    3311           남이장군사당  126.957703
# 17643  100100124  0017  28  102000215    3309         신창동세방아파트  126.954947
# 18436  100100124  0017  29  102000213    3307      산천동.성심여중고후문  126.953382
# 18950  100100124  0017  30  102000211    3305      산천동리버힐삼성아파트  126.951192
# 19439  100100124  0017  31  102000228    3322            삼성테마트  126.950385
# 19685  100100124  0017  32  102000205    3299        원효2동산호아파트  126.950542
# 20198  100100124  0017  33  102000207    3301         원효로풍전아파트  126.953523
# 21082  100100124  0017  34  102000195    3289     성촌공원.포르쉐센터용산  126.954351
# 21362  100100124  0017  35  102000197    3291         이촌2동주민센터  126.954862
# 21813  100100124  0017  36  102000199    3293  이촌2동대림아파트.새남터성지  126.956166
# 22090  100100124  0017  37  102000201    3295        이촌2동강변아파트  126.959781
# 22670  100100124  0017  38  102000001    3001    한강대교북단.LG유플러스  126.963121
# 22940  100100124  0017  39  102000003    3003             신용산역  126.966207
# 23540  100100124  0017  40  102000159    3253         신용산역5번출구  126.967679
# 24113  100100124  0017  41  102000318    3121    용산역3번출구.용산차고지  126.964215
#
#              Y좌표      시    구      동  거리
# 720    37.532590  서울특별시  용산구  한강로3가   0
# 1663   37.528869  서울특별시  용산구  한강로3가   0
# 2683   37.527574  서울특별시  용산구  한강로3가   0
# 3254   37.524968  서울특별시  용산구  한강로3가   0
# 3534   37.523863  서울특별시  용산구  한강로3가   0
# 4655   37.526175  서울특별시  용산구    이촌동   0
# 5258   37.527736  서울특별시  용산구  한강로3가   0
# 5945   37.530171  서울특별시  용산구  한강로3가   0
# 6671   37.530082  서울특별시  용산구    이촌동   0
# 7337   37.532260  서울특별시  용산구  원효로4가   0
# 7787   37.534015  서울특별시  용산구  원효로4가   0
# 8671   37.533887  서울특별시  용산구    산천동   0
# 9434   37.534494  서울특별시  용산구    산천동   0
# 9984   37.535320  서울특별시  용산구    신창동   0
# 10626  37.535708  서울특별시  용산구    신창동   0
# 11377  37.536608  서울특별시  용산구    용문동   0
# 12009  37.537072  서울특별시  용산구    용문동   0
# 12296  37.536348  서울특별시  용산구    용문동   0
# 13245  37.534658  서울특별시  용산구  원효로2가   0
# 13864  37.532590  서울특별시  용산구  한강로3가   0
# 14351  37.528889  서울특별시  용산구  한강로2가   0
# 14742  37.532835  서울특별시  용산구  한강로3가   0
# 15618  37.534570  서울특별시  용산구    신계동   0
# 15934  37.535979  서울특별시  용산구  원효로2가   0
# 16751  37.537149  서울특별시  용산구    용문동   0
# 17281  37.536824  서울특별시  용산구    용문동   0
# 17643  37.535830  서울특별시  용산구    신창동   0
# 18436  37.535408  서울특별시  용산구    신창동   0
# 18950  37.534500  서울특별시  용산구    산천동   0
# 19439  37.533747  서울특별시  용산구  원효로4가   0
# 19685  37.533018  서울특별시  용산구  원효로4가   0
# 20198  37.532129  서울특별시  용산구  원효로4가   0
# 21082  37.529747  서울특별시  용산구    이촌동   0
# 21362  37.527703  서울특별시  용산구    이촌동   0
# 21813  37.526029  서울특별시  용산구    이촌동   0
# 22090  37.523446  서울특별시  용산구    이촌동   0
# 22670  37.524049  서울특별시  용산구  한강로3가   0
# 22940  37.527293  서울특별시  용산구  한강로2가   0
# 23540  37.530034  서울특별시  용산구  한강로2가   0
# 24113  37.531808  서울특별시  용산구  한강로3가   0

# %%
import requests
import numpy as np

def calcDistanceByApi(originX, originY, destX, destY):
    # 2개스페이스로 된 탭으로 보여줍니다.
    # URL 및 헤더 정보
    url = "https://apis-navi.kakaomobility.com/v1/directions"
    headers = {
        "Authorization": "KakaoAK 2a96ad655ffebec848633bc4779b2bf6"
    }

    # 쿼리 파라미터 (Query Parameters)
    # curl 명령어의 '?' 뒤에 오는 부분입니다.
    params = {
        "origin": f"{originX},{originY},angle={calcAngle(originX, originY, destX, destY)}",
        "destination": f"{destX},{destY}",
        "priority": "DISTANCE", # DISTANCE:최단거리, TIME:최단시간, RECOMMEND:추천
        "car_type": "3", # 1:소형,2:중형,3:대형(33인승이상)
        "summary":"true", #요약정보만,
        "avoid":"ferries|uturn",
        "alternatives":"true",
        "roadevent":"2"
    }

    try:
        # GET 요청 보내기
        response = requests.get(url, headers=headers, params=params)

        # 응답 확인
        if response.status_code == 200:
            # 성공 시 JSON 응답 출력
            #print("요청 성공 (Status Code: 200)")
            # print(response.json()) # 전체 JSON 응답을 보고 싶을 때
            
            # 예시로 응답의 주요 정보만 출력
            data = response.json()
            
            # 🌟 수정 부분: 'routes' 키는 확인되었으나, 'summary' 키가 없을 경우 처리
            if 'routes' in data and data['routes']:
                first_route = data['routes'][0]
                
                # 'routes' 리스트의 첫 번째 요소가 예상대로 'summary'를 가지고 있는지 확인
                try:
                    return first_route['summary']['distance']
                
                except KeyError as e:
                    # 1. 'result_code'가 104인지 확인
                    if 'result_code' in first_route and first_route['result_code'] == 104:
                        # result_code 104: "출발지와 도착지가 5 m 이내"
                        # 요청에 따라 5m를 반환합니다.
                        return 5.0 # 거리 단위는 미터(m)

                    # 2. 기타 KeyError 처리 및 디버깅 출력 (이전과 동일)
                    print("-" * 50)
                    print(f"KeyError 발생: {e} 키가 첫 번째 경로 객체에 없습니다.")
                    print("오류 발생 시의 응답 데이터 (data) 전체:")
                    print(data) 
                    print("-" * 50)
                    return np.nan 
                
            else:
                # 'routes' 키가 없거나 리스트가 비어있을 경우 (경로 탐색 실패 등)
                print("경로 데이터가 응답에 포함되어 있지 않거나 비어있습니다.")
                print("응답 데이터 (data) 전체:")
                print(data)
                return np.nan
            
        else:
            # 오류 발생 시 상태 코드 및 내용 출력
            print(f"요청 실패 (Status Code: {response.status_code})")
            print(f"오류 메시지: {response.text}")

    except requests.exceptions.RequestException as e:
        # 네트워크 등 요청 자체의 오류 처리
        print(f"요청 중 오류 발생: {e}=data{data}")

# %%
print("aaa=",calcDistanceByApi(originX, originY, destX, destY))
# Out:
# aaa= 278

# %%
DISTANCE_CACHE = []

# %%
import time
from tqdm import tqdm
import numpy as ny

def calculate_route_distances_pseudo(df):
  """
  인덱스 매핑 오류를 수정한 함수입니다. 원본 인덱스를 저장하여 정확히 매핑합니다.
  """
  # 결과를 담을 새로운 컬럼 초기화
  df['거리'] = 0.0

  # '노선명'을 기준으로 그룹화
  grouped = df.groupby('노선명')

  # 각 노선별로 순회하며 거리 계산
  for route_name, route_df in tqdm(grouped, desc="노선별 거리 계산 진행", total=len(grouped)):
    # 🌟 수정 포인트 1: 원래의 데이터프레임 인덱스를 저장합니다.
    original_indices = route_df.index
    
    # 순번 오름차순으로 정렬 후 인덱스 재설정 (계산 편의를 위해 0, 1, 2...로 만듦)
    route_df = route_df.sort_values(by='순번').reset_index(drop=True)
    
    route_distances = []
    
    # 거리 계산 루프 (N-1)
    for i in range(len(route_df) - 1):
      lat1 = route_df.loc[i, 'Y좌표']
      lon1 = route_df.loc[i, 'X좌표']
      lat2 = route_df.loc[i + 1, 'Y좌표']
      lon2 = route_df.loc[i + 1, 'X좌표']

      cache_key = (lat1, lon1, lat2, lon2)

      print(f"노선={route_df.loc[i, '노선명']},순번={route_df.loc[i, '순번']},key={cache_key}")

# %%
calculate_route_distances_pseudo(src_df)
# Out:
# 노선별 거리 계산 진행:  12%|███████████▊                                                                                      | 85/705 [00:00<00:01, 446.71it/s]
# 노선=0017,순번=2,key=(np.float64(37.53259), np.float64(126.963882), np.float64(37.528869), np.float64(126.965822))
# 노선=0017,순번=3,key=(np.float64(37.528869), np.float64(126.965822), np.float64(37.527574), np.float64(126.964759))
# 노선=0017,순번=4,key=(np.float64(37.527574), np.float64(126.964759), np.float64(37.524968), np.float64(126.96357))
# 노선=0017,순번=5,key=(np.float64(37.524968), np.float64(126.96357), np.float64(37.523863), np.float64(126.959497))
# 노선=0017,순번=6,key=(np.float64(37.523863), np.float64(126.959497), np.float64(37.52617531), np.float64(126.9563231))
# 노선=0017,순번=7,key=(np.float64(37.52617531), np.float64(126.9563231), np.float64(37.52773644), np.float64(126.955064))
# 노선=0017,순번=8,key=(np.float64(37.52773644), np.float64(126.955064), np.float64(37.53017103), np.float64(126.9546065))
# 노선=0017,순번=9,key=(np.float64(37.53017103), np.float64(126.9546065), np.float64(37.530082), np.float64(126.952943))
# 노선=0017,순번=10,key=(np.float64(37.530082), np.float64(126.952943), np.float64(37.53226), np.float64(126.950016))
# 노선=0017,순번=11,key=(np.float64(37.53226), np.float64(126.950016), np.float64(37.534015), np.float64(126.949323))
# 노선=0017,순번=12,key=(np.float64(37.534015), np.float64(126.949323), np.float64(37.533887), np.float64(126.950688))
# 노선=0017,순번=13,key=(np.float64(37.533887), np.float64(126.950688), np.float64(37.534494), np.float64(126.951395))
# 노선=0017,순번=14,key=(np.float64(37.534494), np.float64(126.951395), np.float64(37.53532039), np.float64(126.9536425))
# 노선=0017,순번=15,key=(np.float64(37.53532039), np.float64(126.9536425), np.float64(37.535708), np.float64(126.954955))
# 노선=0017,순번=16,key=(np.float64(37.535708), np.float64(126.954955), np.float64(37.53660802), np.float64(126.9578221))
# 노선=0017,순번=17,key=(np.float64(37.53660802), np.float64(126.9578221), np.float64(37.53707162), np.float64(126.9595338))
# 노선=0017,순번=18,key=(np.float64(37.53707162), np.float64(126.9595338), np.float64(37.536348), np.float64(126.960969))
# 노선=0017,순번=19,key=(np.float64(37.536348), np.float64(126.960969), np.float64(37.534658), np.float64(126.961938))
# 노선=0017,순번=20,key=(np.float64(37.534658), np.float64(126.961938), np.float64(37.53259), np.float64(126.963882))
# 노선=0017,순번=21,key=(np.float64(37.53259), np.float64(126.963882), np.float64(37.528889), np.float64(126.967351))
# 노선=0017,순번=22,key=(np.float64(37.528889), np.float64(126.967351), np.float64(37.53283488), np.float64(126.9636682))
# 노선=0017,순번=23,key=(np.float64(37.53283488), np.float64(126.9636682), np.float64(37.53457017), np.float64(126.9622225))
# 노선=0017,순번=24,key=(np.float64(37.53457017), np.float64(126.9622225), np.float64(37.5359792), np.float64(126.9613596))
# 노선=0017,순번=25,key=(np.float64(37.5359792), np.float64(126.9613596), np.float64(37.53714921), np.float64(126.9591968))
# 노선=0017,순번=26,key=(np.float64(37.53714921), np.float64(126.9591968), np.float64(37.53682386), np.float64(126.9577035))
# 노선=0017,순번=27,key=(np.float64(37.53682386), np.float64(126.9577035), np.float64(37.53583005), np.float64(126.9549471))
# 노선=0017,순번=28,key=(np.float64(37.53583005), np.float64(126.9549471), np.float64(37.53540813), np.float64(126.9533822))
# 노선=0017,순번=29,key=(np.float64(37.53540813), np.float64(126.9533822), np.float64(37.53450034), np.float64(126.9511923))
# 노선=0017,순번=30,key=(np.float64(37.53450034), np.float64(126.9511923), np.float64(37.53374669), np.float64(126.9503849))
# 노선=0017,순번=31,key=(np.float64(37.53374669), np.float64(126.9503849), np.float64(37.53301777), np.float64(126.9505416))
# 노선=0017,순번=32,key=(np.float64(37.53301777), np.float64(126.9505416), np.float64(37.53212865), np.float64(126.9535225))
# 노선=0017,순번=33,key=(np.float64(37.53212865), np.float64(126.9535225), np.float64(37.52974742), np.float64(126.9543511))
# 노선=0017,순번=34,key=(np.float64(37.52974742), np.float64(126.9543511), np.float64(37.527703), np.float64(126.954862))
# 노선=0017,순번=35,key=(np.float64(37.527703), np.float64(126.954862), np.float64(37.52602927), np.float64(126.9561659))
# 노선=0017,순번=36,key=(np.float64(37.52602927), np.float64(126.9561659), np.float64(37.52344621), np.float64(126.959781))
# 노선=0017,순번=37,key=(np.float64(37.52344621), np.float64(126.959781), np.float64(37.524049), np.float64(126.963121))
# 노선=0017,순번=38,key=(np.float64(37.524049), np.float64(126.963121), np.float64(37.527293), np.float64(126.966207))
# 노선=0017,순번=39,key=(np.float64(37.527293), np.float64(126.966207), np.float64(37.53003386), np.float64(126.9676785))
# 노선=0017,순번=40,key=(np.float64(37.53003386), np.float64(126.9676785), np.float64(37.531808), np.float64(126.964215))
# 노선=01A,순번=1,key=(np.float64(37.55974), np.float64(126.989289), np.float64(37.56090197), np.float64(126.9924098))
# 노선=01A,순번=2,key=(np.float64(37.56090197), np.float64(126.9924098), np.float64(37.56123759), np.float64(126.9947285))
# 노선=01A,순번=3,key=(np.float64(37.56123759), np.float64(126.9947285), np.float64(37.56238041), np.float64(126.999966))
# 노선=01A,순번=4,key=(np.float64(37.56238041), np.float64(126.999966), np.float64(37.5601745), np.float64(127.0025921))
# 노선=01A,순번=5,key=(np.float64(37.5601745), np.float64(127.0025921), np.float64(37.558362), np.float64(127.005445))
# 노선=01A,순번=6,key=(np.float64(37.558362), np.float64(127.005445), np.float64(37.551535), np.float64(127.000752))
# 노선=01A,순번=7,key=(np.float64(37.551535), np.float64(127.000752), np.float64(37.55069862), np.float64(126.9988218))
# 노선=01A,순번=8,key=(np.float64(37.55069862), np.float64(126.9988218), np.float64(37.551016), np.float64(126.991197))
# 노선=01A,순번=9,key=(np.float64(37.551016), np.float64(126.991197), np.float64(37.55234367), np.float64(126.9818462))
# 노선=01A,순번=10,key=(np.float64(37.55234367), np.float64(126.9818462), np.float64(37.555737), np.float64(126.980093))
# 노선=01A,순번=11,key=(np.float64(37.555737), np.float64(126.980093), np.float64(37.55662674), np.float64(126.9767113))
# 노선=01A,순번=12,key=(np.float64(37.55662674), np.float64(126.9767113), np.float64(37.5588724), np.float64(126.9759977))
# 노선=01A,순번=13,key=(np.float64(37.5588724), np.float64(126.9759977), np.float64(37.56219717), np.float64(126.9764437))
# 노선=01A,순번=14,key=(np.float64(37.56219717), np.float64(126.9764437), np.float64(37.56836329), np.float64(126.9773647))
# 노선=01A,순번=15,key=(np.float64(37.56836329), np.float64(126.9773647), np.float64(37.57232093), np.float64(126.9774163))
# 노선=01A,순번=16,key=(np.float64(37.57232093), np.float64(126.9774163), np.float64(37.57893039), np.float64(126.9739818))
# 노선=01A,순번=17,key=(np.float64(37.57893039), np.float64(126.9739818), np.float64(37.582971), np.float64(126.973762))
# 노선=01A,순번=18,key=(np.float64(37.582971), np.float64(126.973762), np.float64(37.583126), np.float64(126.979657))
# 노선=01A,순번=19,key=(np.float64(37.583126), np.float64(126.979657), np.float64(37.579407), np.float64(126.97959))
# 노선=01A,순번=20,key=(np.float64(37.579407), np.float64(126.97959), np.float64(37.57579898), np.float64(126.9841344))
# 노선=01A,순번=21,key=(np.float64(37.57579898), np.float64(126.9841344), np.float64(37.57131917), np.float64(126.9874286))
# 노선=01A,순번=22,key=(np.float64(37.57131917), np.float64(126.9874286), np.float64(37.56857927), np.float64(126.9876131))
# 노선=01A,순번=23,key=(np.float64(37.56857927), np.float64(126.9876131), np.float64(37.56498481), np.float64(126.9875299))
# 노선=01A,순번=24,key=(np.float64(37.56498481), np.float64(126.9875299), np.float64(37.55974), np.float64(126.989289))
# 노선=01B,순번=1,key=(np.float64(37.55974), np.float64(126.989289), np.float64(37.56123759), np.float64(126.9947285))
# 노선=01B,순번=2,key=(np.float64(37.56123759), np.float64(126.9947285), np.float64(37.558362), np.float64(127.005445))
# 노선=01B,순번=3,key=(np.float64(37.558362), np.float64(127.005445), np.float64(37.551535), np.float64(127.000752))
# 노선=01B,순번=4,key=(np.float64(37.551535), np.float64(127.000752), np.float64(37.551016), np.float64(126.991197))
# 노선=01B,순번=5,key=(np.float64(37.551016), np.float64(126.991197), np.float64(37.55234367), np.float64(126.9818462))
# 노선=01B,순번=6,key=(np.float64(37.55234367), np.float64(126.9818462), np.float64(37.55526518), np.float64(126.9839798))
# 노선=01B,순번=7,key=(np.float64(37.55526518), np.float64(126.9839798), np.float64(37.55974), np.float64(126.989289))
# 노선=01B,순번=8,key=(np.float64(37.55974), np.float64(126.989289), np.float64(37.56123759), np.float64(126.9947285))
# 노선=01B,순번=9,key=(np.float64(37.56123759), np.float64(126.9947285), np.float64(37.558362), np.float64(127.005445))
# 노선=01B,순번=10,key=(np.float64(37.558362), np.float64(127.005445), np.float64(37.551535), np.float64(127.000752))
# 노선=01B,순번=11,key=(np.float64(37.551535), np.float64(127.000752), np.float64(37.551016), np.float64(126.991197))
# 노선=01B,순번=12,key=(np.float64(37.551016), np.float64(126.991197), np.float64(37.55234367), np.float64(126.9818462))
# 노선=01B,순번=13,key=(np.float64(37.55234367), np.float64(126.9818462), np.float64(37.55526518), np.float64(126.9839798))
# 노선=01B,순번=14,key=(np.float64(37.55526518), np.float64(126.9839798), np.float64(37.55974), np.float64(126.989289))
# 노선=040,순번=1,key=(np.float64(37.53259), np.float64(126.963882), np.float64(37.528869), np.float64(126.965822))
# 노선=040,순번=2,key=(np.float64(37.528869), np.float64(126.965822), np.float64(37.527574), np.float64(126.964759))
# 노선=040,순번=3,key=(np.float64(37.527574), np.float64(126.964759), np.float64(37.524968), np.float64(126.96357))
# 노선=040,순번=4,key=(np.float64(37.524968), np.float64(126.96357), np.float64(37.512865), np.float64(126.951048))
# 노선=040,순번=5,key=(np.float64(37.512865), np.float64(126.951048), np.float64(37.513315), np.float64(126.947977))
# 노선=040,순번=6,key=(np.float64(37.513315), np.float64(126.947977), np.float64(37.513905), np.float64(126.943467))
# 노선=040,순번=7,key=(np.float64(37.513905), np.float64(126.943467), np.float64(37.51055022), np.float64(126.9400541))
# 노선=040,순번=8,key=(np.float64(37.51055022), np.float64(126.9400541), np.float64(37.50821101), np.float64(126.9399682))
# 노선=040,순번=9,key=(np.float64(37.50821101), np.float64(126.9399682), np.float64(37.504993), np.float64(126.94076))
# 노선=040,순번=10,key=(np.float64(37.504993), np.float64(126.94076), np.float64(37.504793), np.float64(126.94594))
# 노선=040,순번=11,key=(np.float64(37.504793), np.float64(126.94594), np.float64(37.50162713), np.float64(126.9486225))
# 노선=040,순번=12,key=(np.float64(37.50162713), np.float64(126.9486225), np.float64(37.49881318), np.float64(126.951185))
# 노선=040,순번=13,key=(np.float64(37.49881318), np.float64(126.951185), np.float64(37.496923), np.float64(126.9528))
# 노선=040,순번=14,key=(np.float64(37.496923), np.float64(126.9528), np.float64(37.49515), np.float64(126.957055))
# 노선=040,순번=15,key=(np.float64(37.49515), np.float64(126.957055), np.float64(37.49463907), np.float64(126.9602929))
# 노선=040,순번=16,key=(np.float64(37.49463907), np.float64(126.9602929), np.float64(37.492436), np.float64(126.963072))
# 노선=040,순번=17,key=(np.float64(37.492436), np.float64(126.963072), np.float64(37.48902778), np.float64(126.9656493))
# 노선=040,순번=18,key=(np.float64(37.48902778), np.float64(126.9656493), np.float64(37.487863), np.float64(126.966476))
# 노선=040,순번=19,key=(np.float64(37.487863), np.float64(126.966476), np.float64(37.486355), np.float64(126.968275))
# 노선=040,순번=20,key=(np.float64(37.486355), np.float64(126.968275), np.float64(37.484588), np.float64(126.971093))
# 노선=040,순번=21,key=(np.float64(37.484588), np.float64(126.971093), np.float64(37.483676), np.float64(126.972782))
# 노선=040,순번=22,key=(np.float64(37.483676), np.float64(126.972782), np.float64(37.483377), np.float64(126.97629))
# 노선=040,순번=23,key=(np.float64(37.483377), np.float64(126.97629), np.float64(37.484075), np.float64(126.978585))
# 노선=040,순번=24,key=(np.float64(37.484075), np.float64(126.978585), np.float64(37.484445), np.float64(126.979895))
# 노선=040,순번=25,key=(np.float64(37.484445), np.float64(126.979895), np.float64(37.48548936), np.float64(126.9842073))
# 노선=040,순번=26,key=(np.float64(37.48548936), np.float64(126.9842073), np.float64(37.48574026), np.float64(126.9864538))
# 노선=040,순번=27,key=(np.float64(37.48574026), np.float64(126.9864538), np.float64(37.486497), np.float64(126.99018))
# 노선=040,순번=28,key=(np.float64(37.486497), np.float64(126.99018), np.float64(37.487993), np.float64(126.995335))
# 노선=040,순번=29,key=(np.float64(37.487993), np.float64(126.995335), np.float64(37.491003), np.float64(127.005496))
# 노선=040,순번=30,key=(np.float64(37.491003), np.float64(127.005496), np.float64(37.492017), np.float64(127.00891))
# 노선=040,순번=31,key=(np.float64(37.492017), np.float64(127.00891), np.float64(37.49402421), np.float64(127.0153818))
# 노선=040,순번=32,key=(np.float64(37.49402421), np.float64(127.0153818), np.float64(37.49545694), np.float64(127.020216))
# 노선=040,순번=33,key=(np.float64(37.49545694), np.float64(127.020216), np.float64(37.49665727), np.float64(127.0240036))
# 노선=040,순번=34,key=(np.float64(37.49665727), np.float64(127.0240036), np.float64(37.49829745), np.float64(127.0290968))
# 노선=040,순번=35,key=(np.float64(37.49829745), np.float64(127.0290968), np.float64(37.49949), np.float64(127.033598))
# 노선=040,순번=36,key=(np.float64(37.49949), np.float64(127.033598), np.float64(37.501137), np.float64(127.038818))
# 노선=040,순번=37,key=(np.float64(37.501137), np.float64(127.038818), np.float64(37.49987934), np.float64(127.0437951))
# 노선=040,순번=38,key=(np.float64(37.49987934), np.float64(127.0437951), np.float64(37.49604364), np.float64(127.0457084))
# 노선=040,순번=39,key=(np.float64(37.49604364), np.float64(127.0457084), np.float64(37.49360204), np.float64(127.0467216))
# 노선=040,순번=40,key=(np.float64(37.49360204), np.float64(127.0467216), np.float64(37.48708516), np.float64(127.050373))
# 노선=040,순번=41,key=(np.float64(37.48708516), np.float64(127.050373), np.float64(37.48226538), np.float64(127.0528285))
# 노선=040,순번=42,key=(np.float64(37.48226538), np.float64(127.0528285), np.float64(37.479942), np.float64(127.054609))
# 노선=040,순번=43,key=(np.float64(37.479942), np.float64(127.054609), np.float64(37.47656443), np.float64(127.0578639))
# 노선=040,순번=44,key=(np.float64(37.47656443), np.float64(127.0578639), np.float64(37.477328), np.float64(127.057772))
# 노선=040,순번=45,key=(np.float64(37.477328), np.float64(127.057772), np.float64(37.478381), np.float64(127.056741))
# 노선=040,순번=46,key=(np.float64(37.478381), np.float64(127.056741), np.float64(37.48090349), np.float64(127.0542007))
# 노선=040,순번=47,key=(np.float64(37.48090349), np.float64(127.0542007), np.float64(37.482875), np.float64(127.053115))
# 노선=040,순번=48,key=(np.float64(37.482875), np.float64(127.053115), np.float64(37.48700968), np.float64(127.0508009))
# 노선=040,순번=49,key=(np.float64(37.48700968), np.float64(127.0508009), np.float64(37.493352), np.float64(127.04746))
# 노선=040,순번=50,key=(np.float64(37.493352), np.float64(127.04746), np.float64(37.498146), np.float64(127.043699))
# 노선=040,순번=51,key=(np.float64(37.498146), np.float64(127.043699), np.float64(37.4966905), np.float64(127.0408425))
# 노선=040,순번=52,key=(np.float64(37.4966905), np.float64(127.0408425), np.float64(37.49433084), np.float64(127.0341054))
# 노선=040,순번=53,key=(np.float64(37.49433084), np.float64(127.0341054), np.float64(37.496548), np.float64(127.032341))
# 노선=040,순번=54,key=(np.float64(37.496548), np.float64(127.032341), np.float64(37.49881), np.float64(127.029558))
# 노선=040,순번=55,key=(np.float64(37.49881), np.float64(127.029558), np.float64(37.497784), np.float64(127.0266041))
# 노선=040,순번=56,key=(np.float64(37.497784), np.float64(127.0266041), np.float64(37.49657912), np.float64(127.0227753))
# 노선=040,순번=57,key=(np.float64(37.49657912), np.float64(127.0227753), np.float64(37.49575), np.float64(127.01977))
# 노선=040,순번=58,key=(np.float64(37.49575), np.float64(127.01977), np.float64(37.49447257), np.float64(127.0158387))
# 노선=040,순번=59,key=(np.float64(37.49447257), np.float64(127.0158387), np.float64(37.493554), np.float64(127.012781))
# 노선=040,순번=60,key=(np.float64(37.493554), np.float64(127.012781), np.float64(37.49167), np.float64(127.006529))
# 노선=040,순번=61,key=(np.float64(37.49167), np.float64(127.006529), np.float64(37.487527), np.float64(126.992748))
# 노선=040,순번=62,key=(np.float64(37.487527), np.float64(126.992748), np.float64(37.48638864), np.float64(126.9888062))
# 노선=040,순번=63,key=(np.float64(37.48638864), np.float64(126.9888062), np.float64(37.485864), np.float64(126.984646))
# 노선=040,순번=64,key=(np.float64(37.485864), np.float64(126.984646), np.float64(37.48483286), np.float64(126.9801875))
# 노선=040,순번=65,key=(np.float64(37.48483286), np.float64(126.9801875), np.float64(37.48429923), np.float64(126.97843))
# 노선=040,순번=66,key=(np.float64(37.48429923), np.float64(126.97843), np.float64(37.483805), np.float64(126.973014))
# 노선=040,순번=67,key=(np.float64(37.483805), np.float64(126.973014), np.float64(37.48492912), np.float64(126.9707465))
# 노선=040,순번=68,key=(np.float64(37.48492912), np.float64(126.9707465), np.float64(37.48663695), np.float64(126.9681789))
# 노선=040,순번=69,key=(np.float64(37.48663695), np.float64(126.9681789), np.float64(37.48874228), np.float64(126.9661798))
# 노선=040,순번=70,key=(np.float64(37.48874228), np.float64(126.9661798), np.float64(37.492298), np.float64(126.963578))
# 노선=040,순번=71,key=(np.float64(37.492298), np.float64(126.963578), np.float64(37.494983), np.float64(126.959895))
# 노선=040,순번=72,key=(np.float64(37.494983), np.float64(126.959895), np.float64(37.49531836), np.float64(126.9572808))
# 노선=040,순번=73,key=(np.float64(37.49531836), np.float64(126.9572808), np.float64(37.49646142), np.float64(126.9537335))
# 노선=040,순번=74,key=(np.float64(37.49646142), np.float64(126.9537335), np.float64(37.49868997), np.float64(126.9517744))
# 노선=040,순번=75,key=(np.float64(37.49868997), np.float64(126.9517744), np.float64(37.50124906), np.float64(126.9495197))
# 노선=040,순번=76,key=(np.float64(37.50124906), np.float64(126.9495197), np.float64(37.50432696), np.float64(126.9468675))
# 노선=040,순번=77,key=(np.float64(37.50432696), np.float64(126.9468675), np.float64(37.50532973), np.float64(126.9417293))
# 노선=040,순번=78,key=(np.float64(37.50532973), np.float64(126.9417293), np.float64(37.50724508), np.float64(126.9400798))
# 노선=040,순번=79,key=(np.float64(37.50724508), np.float64(126.9400798), np.float64(37.510453), np.float64(126.940337))
# 노선=040,순번=80,key=(np.float64(37.510453), np.float64(126.940337), np.float64(37.513495), np.float64(126.941878))
# 노선=040,순번=81,key=(np.float64(37.513495), np.float64(126.941878), np.float64(37.512825), np.float64(126.949256))
# 노선=040,순번=82,key=(np.float64(37.512825), np.float64(126.949256), np.float64(37.524049), np.float64(126.963121))
# 노선=040,순번=83,key=(np.float64(37.524049), np.float64(126.963121), np.float64(37.527293), np.float64(126.966207))
# 노선=040,순번=84,key=(np.float64(37.527293), np.float64(126.966207), np.float64(37.531808), np.float64(126.964215))
# 노선=0411,순번=1,key=(np.float64(37.53216), np.float64(126.96306), np.float64(37.533058), np.float64(126.958339))
# 노선=0411,순번=2,key=(np.float64(37.533058), np.float64(126.958339), np.float64(37.53379572), np.float64(126.9583248))
# 노선=0411,순번=3,key=(np.float64(37.53379572), np.float64(126.9583248), np.float64(37.53493384), np.float64(126.9610704))
# 노선=0411,순번=4,key=(np.float64(37.53493384), np.float64(126.9610704), np.float64(37.53631875), np.float64(126.9636632))
# 노선=0411,순번=5,key=(np.float64(37.53631875), np.float64(126.9636632), np.float64(37.53842682), np.float64(126.9649998))
# 노선=0411,순번=6,key=(np.float64(37.53842682), np.float64(126.9649998), np.float64(37.539267), np.float64(126.9619))
# 노선=0411,순번=7,key=(np.float64(37.539267), np.float64(126.9619), np.float64(37.54162396), np.float64(126.9622337))
# 노선=0411,순번=8,key=(np.float64(37.54162396), np.float64(126.9622337), np.float64(37.54460709), np.float64(126.9638369))
# 노선=0411,순번=9,key=(np.float64(37.54460709), np.float64(126.9638369), np.float64(37.546091), np.float64(126.963307))
# 노선=0411,순번=10,key=(np.float64(37.546091), np.float64(126.963307), np.float64(37.546794), np.float64(126.962579))
# 노선=0411,순번=11,key=(np.float64(37.546794), np.float64(126.962579), np.float64(37.54588062), np.float64(126.9591929))
# 노선=0411,순번=12,key=(np.float64(37.54588062), np.float64(126.9591929), np.float64(37.54378904), np.float64(126.9576684))
# 노선=0411,순번=13,key=(np.float64(37.54378904), np.float64(126.9576684), np.float64(37.54220952), np.float64(126.9617671))
# 노선=0411,순번=14,key=(np.float64(37.54220952), np.float64(126.9617671), np.float64(37.541299), np.float64(126.962009))
# 노선=0411,순번=15,key=(np.float64(37.541299), np.float64(126.962009), np.float64(37.538826), np.float64(126.962698))
# 노선=0411,순번=16,key=(np.float64(37.538826), np.float64(126.962698), np.float64(37.538295), np.float64(126.964648))
# 노선=0411,순번=17,key=(np.float64(37.538295), np.float64(126.964648), np.float64(37.53623744), np.float64(126.9629911))
# 노선=0411,순번=18,key=(np.float64(37.53623744), np.float64(126.9629911), np.float64(37.53404076), np.float64(126.9581798))
# 노선=0411,순번=19,key=(np.float64(37.53404076), np.float64(126.9581798), np.float64(37.532743), np.float64(126.955917))
# 노선=0411,순번=20,key=(np.float64(37.532743), np.float64(126.955917), np.float64(37.52974742), np.float64(126.9543511))
# 노선=0411,순번=21,key=(np.float64(37.52974742), np.float64(126.9543511), np.float64(37.527703), np.float64(126.954862))
# 노선=0411,순번=22,key=(np.float64(37.527703), np.float64(126.954862), np.float64(37.52602927), np.float64(126.9561659))
# 노선=0411,순번=23,key=(np.float64(37.52602927), np.float64(126.9561659), np.float64(37.52344621), np.float64(126.959781))
# 노선=0411,순번=24,key=(np.float64(37.52344621), np.float64(126.959781), np.float64(37.521567), np.float64(126.966008))
# 노선=0411,순번=25,key=(np.float64(37.521567), np.float64(126.966008), np.float64(37.521285), np.float64(126.96848))
# 노선=0411,순번=26,key=(np.float64(37.521285), np.float64(126.96848), np.float64(37.52018), np.float64(126.97271))
# 노선=0411,순번=27,key=(np.float64(37.52018), np.float64(126.97271), np.float64(37.51908), np.float64(126.976238))
# 노선=0411,순번=28,key=(np.float64(37.51908), np.float64(126.976238), np.float64(37.51834003), np.float64(126.9783561))
# 노선=0411,순번=29,key=(np.float64(37.51834003), np.float64(126.9783561), np.float64(37.51770433), np.float64(126.9811234))
# 노선=0411,순번=30,key=(np.float64(37.51770433), np.float64(126.9811234), np.float64(37.51748597), np.float64(126.9853714))
# 노선=0411,순번=31,key=(np.float64(37.51748597), np.float64(126.9853714), np.float64(37.50576281), np.float64(126.9802792))
# 노선=0411,순번=32,key=(np.float64(37.50576281), np.float64(126.9802792), np.float64(37.501735), np.float64(126.98907))
# 노선=0411,순번=33,key=(np.float64(37.501735), np.float64(126.98907), np.float64(37.503052), np.float64(126.994697))
# 노선=0411,순번=34,key=(np.float64(37.503052), np.float64(126.994697), np.float64(37.505843), np.float64(127.003922))
# 노선=0411,순번=35,key=(np.float64(37.505843), np.float64(127.003922), np.float64(37.50170172), np.float64(127.011583))
# 노선=0411,순번=36,key=(np.float64(37.50170172), np.float64(127.011583), np.float64(37.496385), np.float64(127.013))
# 노선=0411,순번=37,key=(np.float64(37.496385), np.float64(127.013), np.float64(37.49402421), np.float64(127.0153818))
# 노선=0411,순번=38,key=(np.float64(37.49402421), np.float64(127.0153818), np.float64(37.49545694), np.float64(127.020216))
# 노선=0411,순번=39,key=(np.float64(37.49545694), np.float64(127.020216), np.float64(37.49665727), np.float64(127.0240036))
# 노선=0411,순번=40,key=(np.float64(37.49665727), np.float64(127.0240036), np.float64(37.495848), np.float64(127.028538))
# 노선=0411,순번=41,key=(np.float64(37.495848), np.float64(127.028538), np.float64(37.491895), np.float64(127.030405))
# 노선=0411,순번=42,key=(np.float64(37.491895), np.float64(127.030405), np.float64(37.487667), np.float64(127.032432))
# 노선=0411,순번=43,key=(np.float64(37.487667), np.float64(127.032432), np.float64(37.48261), np.float64(127.035902))
# 노선=0411,순번=44,key=(np.float64(37.48261), np.float64(127.035902), np.float64(37.47859), np.float64(127.038482))
# 노선=0411,순번=45,key=(np.float64(37.47859), np.float64(127.038482), np.float64(37.473135), np.float64(127.038353))
# 노선=0411,순번=46,key=(np.float64(37.473135), np.float64(127.038353), np.float64(37.468707), np.float64(127.039655))
# 노선=0411,순번=47,key=(np.float64(37.468707), np.float64(127.039655), np.float64(37.46958572), np.float64(127.0394643))
# 노선=0411,순번=49,key=(np.float64(37.46958572), np.float64(127.0394643), np.float64(37.47327954), np.float64(127.0389281))
# 노선=0411,순번=50,key=(np.float64(37.47327954), np.float64(127.0389281), np.float64(37.477657), np.float64(127.038748))
# 노선=0411,순번=51,key=(np.float64(37.477657), np.float64(127.038748), np.float64(37.481927), np.float64(127.036827))
# 노선=0411,순번=52,key=(np.float64(37.481927), np.float64(127.036827), np.float64(37.486653), np.float64(127.033097))
# 노선=0411,순번=53,key=(np.float64(37.486653), np.float64(127.033097), np.float64(37.491087), np.float64(127.030987))
# 노선=0411,순번=54,key=(np.float64(37.491087), np.float64(127.030987), np.float64(37.494993), np.float64(127.029112))
# 노선=0411,순번=55,key=(np.float64(37.494993), np.float64(127.029112), np.float64(37.49657912), np.float64(127.0227753))
# 노선=0411,순번=56,key=(np.float64(37.49657912), np.float64(127.0227753), np.float64(37.49575), np.float64(127.01977))
# 노선=0411,순번=57,key=(np.float64(37.49575), np.float64(127.01977), np.float64(37.49447257), np.float64(127.0158387))
# 노선=0411,순번=58,key=(np.float64(37.49447257), np.float64(127.0158387), np.float64(37.49628501), np.float64(127.0132447))
# 노선=0411,순번=59,key=(np.float64(37.49628501), np.float64(127.0132447), np.float64(37.49966282), np.float64(127.0124492))
# 노선=0411,순번=60,key=(np.float64(37.49966282), np.float64(127.0124492), np.float64(37.50279745), np.float64(127.0116013))
# 노선=0411,순번=61,key=(np.float64(37.50279745), np.float64(127.0116013), np.float64(37.506295), np.float64(127.005137))
# 노선=0411,순번=62,key=(np.float64(37.506295), np.float64(127.005137), np.float64(37.50345786), np.float64(126.9956954))
# 노선=0411,순번=63,key=(np.float64(37.50345786), np.float64(126.9956954), np.float64(37.50203716), np.float64(126.9899766))
# 노선=0411,순번=64,key=(np.float64(37.50203716), np.float64(126.9899766), np.float64(37.505858), np.float64(126.980812))
# 노선=0411,순번=65,key=(np.float64(37.505858), np.float64(126.980812), np.float64(37.520036), np.float64(126.989482))
# 노선=0411,순번=66,key=(np.float64(37.520036), np.float64(126.989482), np.float64(37.517927), np.float64(126.985098))
# 노선=0411,순번=67,key=(np.float64(37.517927), np.float64(126.985098), np.float64(37.51853368), np.float64(126.978712))
# 노선=0411,순번=68,key=(np.float64(37.51853368), np.float64(126.978712), np.float64(37.518917), np.float64(126.977522))
# 노선=0411,순번=69,key=(np.float64(37.518917), np.float64(126.977522), np.float64(37.519848), np.float64(126.974505))
# 노선=0411,순번=70,key=(np.float64(37.519848), np.float64(126.974505), np.float64(37.5206563), np.float64(126.9718843))
# 노선=0411,순번=71,key=(np.float64(37.5206563), np.float64(126.9718843), np.float64(37.521573), np.float64(126.967528))
# 노선=0411,순번=72,key=(np.float64(37.521573), np.float64(126.967528), np.float64(37.523863), np.float64(126.959497))
# 노선=0411,순번=73,key=(np.float64(37.523863), np.float64(126.959497), np.float64(37.52617531), np.float64(126.9563231))
# 노선=0411,순번=74,key=(np.float64(37.52617531), np.float64(126.9563231), np.float64(37.52773644), np.float64(126.955064))
# 노선=0411,순번=75,key=(np.float64(37.52773644), np.float64(126.955064), np.float64(37.53017103), np.float64(126.9546065))
# 노선=0411,순번=76,key=(np.float64(37.53017103), np.float64(126.9546065), np.float64(37.530082), np.float64(126.952943))
# 노선=0411,순번=77,key=(np.float64(37.530082), np.float64(126.952943), np.float64(37.53212865), np.float64(126.9535225))
# 노선=0411,순번=78,key=(np.float64(37.53212865), np.float64(126.9535225), np.float64(37.53379572), np.float64(126.9583248))
# 노선=0411,순번=79,key=(np.float64(37.53379572), np.float64(126.9583248), np.float64(37.53493384), np.float64(126.9610704))
# 노선=0411,순번=80,key=(np.float64(37.53493384), np.float64(126.9610704), np.float64(37.53631875), np.float64(126.9636632))
# 노선=0411,순번=81,key=(np.float64(37.53631875), np.float64(126.9636632), np.float64(37.53842682), np.float64(126.9649998))
# 노선=0411,순번=82,key=(np.float64(37.53842682), np.float64(126.9649998), np.float64(37.539267), np.float64(126.9619))
# 노선=0411,순번=83,key=(np.float64(37.539267), np.float64(126.9619), np.float64(37.54162396), np.float64(126.9622337))
# 노선=0411,순번=84,key=(np.float64(37.54162396), np.float64(126.9622337), np.float64(37.54460709), np.float64(126.9638369))
# 노선=0411,순번=85,key=(np.float64(37.54460709), np.float64(126.9638369), np.float64(37.546091), np.float64(126.963307))
# 노선=0411,순번=86,key=(np.float64(37.546091), np.float64(126.963307), np.float64(37.546794), np.float64(126.962579))
# 노선=0411,순번=87,key=(np.float64(37.546794), np.float64(126.962579), np.float64(37.54588062), np.float64(126.9591929))
# 노선=0411,순번=88,key=(np.float64(37.54588062), np.float64(126.9591929), np.float64(37.54378904), np.float64(126.9576684))
# 노선=0411,순번=89,key=(np.float64(37.54378904), np.float64(126.9576684), np.float64(37.54220952), np.float64(126.9617671))
# 노선=0411,순번=90,key=(np.float64(37.54220952), np.float64(126.9617671), np.float64(37.541299), np.float64(126.962009))
# 노선=0411,순번=91,key=(np.float64(37.541299), np.float64(126.962009), np.float64(37.538826), np.float64(126.962698))
# 노선=0411,순번=92,key=(np.float64(37.538826), np.float64(126.962698), np.float64(37.538295), np.float64(126.964648))
# 노선=0411,순번=93,key=(np.float64(37.538295), np.float64(126.964648), np.float64(37.53623744), np.float64(126.9629911))
# 노선=0411,순번=94,key=(np.float64(37.53623744), np.float64(126.9629911), np.float64(37.534658), np.float64(126.961938))
# 노선=0411,순번=95,key=(np.float64(37.534658), np.float64(126.961938), np.float64(37.531808), np.float64(126.964215))
# 노선=100,순번=1,key=(np.float64(37.63813), np.float64(127.070056), np.float64(37.63934286), np.float64(127.0689347))
# 노선=100,순번=2,key=(np.float64(37.63934286), np.float64(127.0689347), np.float64(37.639748), np.float64(127.066741))
# 노선=100,순번=3,key=(np.float64(37.639748), np.float64(127.066741), np.float64(37.64322), np.float64(127.065089))
# 노선=100,순번=4,key=(np.float64(37.64322), np.float64(127.065089), np.float64(37.64561755), np.float64(127.0649391))
# 노선=100,순번=5,key=(np.float64(37.64561755), np.float64(127.0649391), np.float64(37.6475), np.float64(127.0679665))
# 노선=100,순번=6,key=(np.float64(37.6475), np.float64(127.0679665), np.float64(37.64685822), np.float64(127.0698766))
# 노선=100,순번=7,key=(np.float64(37.64685822), np.float64(127.0698766), np.float64(37.64353141), np.float64(127.0714067))
# 노선=100,순번=8,key=(np.float64(37.64353141), np.float64(127.0714067), np.float64(37.642018), np.float64(127.072132))
# 노선=100,순번=9,key=(np.float64(37.642018), np.float64(127.072132), np.float64(37.64042632), np.float64(127.0728303))
# 노선=100,순번=10,key=(np.float64(37.64042632), np.float64(127.0728303), np.float64(37.638345), np.float64(127.074233))
# 노선=100,순번=11,key=(np.float64(37.638345), np.float64(127.074233), np.float64(37.63685375), np.float64(127.0694876))
# 노선=100,순번=12,key=(np.float64(37.63685375), np.float64(127.0694876), np.float64(37.63514), np.float64(127.066652))
# 노선=100,순번=13,key=(np.float64(37.63514), np.float64(127.066652), np.float64(37.633833), np.float64(127.064587))
# 노선=100,순번=14,key=(np.float64(37.633833), np.float64(127.064587), np.float64(37.631974), np.float64(127.061623))
# 노선=100,순번=15,key=(np.float64(37.631974), np.float64(127.061623), np.float64(37.6279838), np.float64(127.0552744))
# 노선=100,순번=16,key=(np.float64(37.6279838), np.float64(127.0552744), np.float64(37.62618916), np.float64(127.0525926))
# 노선=100,순번=17,key=(np.float64(37.62618916), np.float64(127.0525926), np.float64(37.62341309), np.float64(127.0479844))
# 노선=100,순번=18,key=(np.float64(37.62341309), np.float64(127.0479844), np.float64(37.62086498), np.float64(127.0453126))
# 노선=100,순번=19,key=(np.float64(37.62086498), np.float64(127.0453126), np.float64(37.61917134), np.float64(127.0442547))
# 노선=100,순번=20,key=(np.float64(37.61917134), np.float64(127.0442547), np.float64(37.61374991), np.float64(127.0379534))
# 노선=100,순번=21,key=(np.float64(37.61374991), np.float64(127.0379534), np.float64(37.61199777), np.float64(127.0354112))
# 노선=100,순번=22,key=(np.float64(37.61199777), np.float64(127.0354112), np.float64(37.610022), np.float64(127.031828))
# 노선=100,순번=23,key=(np.float64(37.610022), np.float64(127.031828), np.float64(37.60690619), np.float64(127.0282093))
# 노선=100,순번=24,key=(np.float64(37.60690619), np.float64(127.0282093), np.float64(37.60375024), np.float64(127.0242689))
# 노선=100,순번=25,key=(np.float64(37.60375024), np.float64(127.0242689), np.float64(37.5988113), np.float64(127.0217091))
# 노선=100,순번=26,key=(np.float64(37.5988113), np.float64(127.0217091), np.float64(37.59374328), np.float64(127.0181314))
# 노선=100,순번=27,key=(np.float64(37.59374328), np.float64(127.0181314), np.float64(37.58996484), np.float64(127.0093351))
# 노선=100,순번=28,key=(np.float64(37.58996484), np.float64(127.0093351), np.float64(37.586243), np.float64(127.001744))
# 노선=100,순번=29,key=(np.float64(37.586243), np.float64(127.001744), np.float64(37.582581), np.float64(126.998251))
# 노선=100,순번=30,key=(np.float64(37.582581), np.float64(126.998251), np.float64(37.579433), np.float64(126.996522))
# 노선=100,순번=31,key=(np.float64(37.579433), np.float64(126.996522), np.float64(37.57453251), np.float64(126.9973383))
# 노선=100,순번=32,key=(np.float64(37.57453251), np.float64(126.9973383), np.float64(37.5694708), np.float64(126.9977438))
# 노선=100,순번=33,key=(np.float64(37.5694708), np.float64(126.9977438), np.float64(37.566687), np.float64(126.995933))
# 노선=100,순번=34,key=(np.float64(37.566687), np.float64(126.995933), np.float64(37.566375), np.float64(126.990263))
# 노선=100,순번=35,key=(np.float64(37.566375), np.float64(126.990263), np.float64(37.56624623), np.float64(126.9865234))
# 노선=100,순번=36,key=(np.float64(37.56624623), np.float64(126.9865234), np.float64(37.56451), np.float64(126.982205))
# 노선=100,순번=37,key=(np.float64(37.56451), np.float64(126.982205), np.float64(37.561273), np.float64(126.978555))
# 노선=100,순번=38,key=(np.float64(37.561273), np.float64(126.978555), np.float64(37.55979677), np.float64(126.9743556))
# 노선=100,순번=39,key=(np.float64(37.55979677), np.float64(126.9743556), np.float64(37.55863886), np.float64(126.9737784))
# 노선=100,순번=40,key=(np.float64(37.55863886), np.float64(126.9737784), np.float64(37.55540298), np.float64(126.9725925))
# 노선=100,순번=41,key=(np.float64(37.55540298), np.float64(126.9725925), np.float64(37.54953372), np.float64(126.9717082))
# 노선=100,순번=42,key=(np.float64(37.54953372), np.float64(126.9717082), np.float64(37.54375602), np.float64(126.9722321))
# 노선=100,순번=43,key=(np.float64(37.54375602), np.float64(126.9722321), np.float64(37.5359845), np.float64(126.9741609))
# 노선=100,순번=44,key=(np.float64(37.5359845), np.float64(126.9741609), np.float64(37.53205037), np.float64(126.9705641))
# 노선=100,순번=45,key=(np.float64(37.53205037), np.float64(126.9705641), np.float64(37.52792049), np.float64(126.9666192))
# 노선=100,순번=46,key=(np.float64(37.52792049), np.float64(126.9666192), np.float64(37.52430606), np.float64(126.9631848))
# 노선=100,순번=47,key=(np.float64(37.52430606), np.float64(126.9631848), np.float64(37.521567), np.float64(126.966008))
# 노선=100,순번=48,key=(np.float64(37.521567), np.float64(126.966008), np.float64(37.521285), np.float64(126.96848))
# 노선=100,순번=49,key=(np.float64(37.521285), np.float64(126.96848), np.float64(37.52018), np.float64(126.97271))
# 노선=100,순번=50,key=(np.float64(37.52018), np.float64(126.97271), np.float64(37.51908), np.float64(126.976238))
# 노선=100,순번=51,key=(np.float64(37.51908), np.float64(126.976238), np.float64(37.51834003), np.float64(126.9783561))
# 노선=100,순번=52,key=(np.float64(37.51834003), np.float64(126.9783561), np.float64(37.51770433), np.float64(126.9811234))
# 노선=100,순번=53,key=(np.float64(37.51770433), np.float64(126.9811234), np.float64(37.51748597), np.float64(126.9853714))
# 노선=100,순번=54,key=(np.float64(37.51748597), np.float64(126.9853714), np.float64(37.520046), np.float64(126.989955))
# 노선=100,순번=55,key=(np.float64(37.520046), np.float64(126.989955), np.float64(37.52545), np.float64(126.992155))
# 노선=100,순번=56,key=(np.float64(37.52545), np.float64(126.992155), np.float64(37.530303), np.float64(126.991163))
# 노선=100,순번=57,key=(np.float64(37.530303), np.float64(126.991163), np.float64(37.529405), np.float64(126.99116))
# 노선=100,순번=58,key=(np.float64(37.529405), np.float64(126.99116), np.float64(37.525117), np.float64(126.991363))
# 노선=100,순번=59,key=(np.float64(37.525117), np.float64(126.991363), np.float64(37.52263626), np.float64(126.9907182))
# 노선=100,순번=60,key=(np.float64(37.52263626), np.float64(126.9907182), np.float64(37.52084129), np.float64(126.99061))
# 노선=100,순번=61,key=(np.float64(37.52084129), np.float64(126.99061), np.float64(37.520427), np.float64(126.9899))
# 노선=100,순번=62,key=(np.float64(37.520427), np.float64(126.9899), np.float64(37.520036), np.float64(126.989482))
# 노선=100,순번=63,key=(np.float64(37.520036), np.float64(126.989482), np.float64(37.517927), np.float64(126.985098))
# 노선=100,순번=64,key=(np.float64(37.517927), np.float64(126.985098), np.float64(37.51853368), np.float64(126.978712))
# 노선=100,순번=65,key=(np.float64(37.51853368), np.float64(126.978712), np.float64(37.518917), np.float64(126.977522))
# 노선=100,순번=66,key=(np.float64(37.518917), np.float64(126.977522), np.float64(37.519848), np.float64(126.974505))
# 노선=100,순번=67,key=(np.float64(37.519848), np.float64(126.974505), np.float64(37.5206563), np.float64(126.9718843))
# 노선=100,순번=68,key=(np.float64(37.5206563), np.float64(126.9718843), np.float64(37.521573), np.float64(126.967528))
# 노선=100,순번=69,key=(np.float64(37.521573), np.float64(126.967528), np.float64(37.524049), np.float64(126.963121))
# 노선=100,순번=70,key=(np.float64(37.524049), np.float64(126.963121), np.float64(37.527293), np.float64(126.966207))
# 노선=100,순번=71,key=(np.float64(37.527293), np.float64(126.966207), np.float64(37.53149701), np.float64(126.970235))
# 노선=100,순번=72,key=(np.float64(37.53149701), np.float64(126.970235), np.float64(37.535181), np.float64(126.973683))
# 노선=100,순번=73,key=(np.float64(37.535181), np.float64(126.973683), np.float64(37.54329563), np.float64(126.9725378))
# 노선=100,순번=74,key=(np.float64(37.54329563), np.float64(126.9725378), np.float64(37.5509756), np.float64(126.9722373))
# 노선=100,순번=75,key=(np.float64(37.5509756), np.float64(126.9722373), np.float64(37.555411), np.float64(126.972926))
# 노선=100,순번=76,key=(np.float64(37.555411), np.float64(126.972926), np.float64(37.56093942), np.float64(126.9785804))
# 노선=100,순번=77,key=(np.float64(37.56093942), np.float64(126.9785804), np.float64(37.562885), np.float64(126.982008))
# 노선=100,순번=78,key=(np.float64(37.562885), np.float64(126.982008), np.float64(37.56587574), np.float64(126.9853903))
# 노선=100,순번=79,key=(np.float64(37.56587574), np.float64(126.9853903), np.float64(37.566072), np.float64(126.98867))
# 노선=100,순번=80,key=(np.float64(37.566072), np.float64(126.98867), np.float64(37.56612052), np.float64(126.9913276))
# 노선=100,순번=81,key=(np.float64(37.56612052), np.float64(126.9913276), np.float64(37.56640104), np.float64(126.9968473))
# 노선=100,순번=82,key=(np.float64(37.56640104), np.float64(126.9968473), np.float64(37.56662004), np.float64(127.001115))
# 노선=100,순번=83,key=(np.float64(37.56662004), np.float64(127.001115), np.float64(37.566173), np.float64(127.006233))
# 노선=100,순번=84,key=(np.float64(37.566173), np.float64(127.006233), np.float64(37.56505283), np.float64(127.0072097))
# 노선=100,순번=85,key=(np.float64(37.56505283), np.float64(127.0072097), np.float64(37.56352844), np.float64(127.0033758))
# 노선=100,순번=86,key=(np.float64(37.56352844), np.float64(127.0033758), np.float64(37.56582435), np.float64(127.0025946))
# 노선=100,순번=87,key=(np.float64(37.56582435), np.float64(127.0025946), np.float64(37.56796085), np.float64(127.0024045))
# 노선=100,순번=88,key=(np.float64(37.56796085), np.float64(127.0024045), np.float64(37.5705596), np.float64(127.0021827))
# 노선=100,순번=89,key=(np.float64(37.5705596), np.float64(127.0021827), np.float64(37.57287901), np.float64(127.0021442))
# 노선=100,순번=90,key=(np.float64(37.57287901), np.float64(127.0021442), np.float64(37.5745), np.float64(127.00223))
# 노선=100,순번=91,key=(np.float64(37.5745), np.float64(127.00223), np.float64(37.578043), np.float64(127.002437))
# 노선=100,순번=92,key=(np.float64(37.578043), np.float64(127.002437), np.float64(37.58111949), np.float64(127.0022769))
# 노선=100,순번=93,key=(np.float64(37.58111949), np.float64(127.0022769), np.float64(37.58453294), np.float64(127.0015562))
# 노선=100,순번=94,key=(np.float64(37.58453294), np.float64(127.0015562), np.float64(37.5893633), np.float64(127.0082049))
# 노선=100,순번=95,key=(np.float64(37.5893633), np.float64(127.0082049), np.float64(37.593251), np.float64(127.017684))
# 노선=100,순번=96,key=(np.float64(37.593251), np.float64(127.017684), np.float64(37.597921), np.float64(127.0218209))
# 노선=100,순번=97,key=(np.float64(37.597921), np.float64(127.0218209), np.float64(37.603112), np.float64(127.023443))
# 노선=100,순번=98,key=(np.float64(37.603112), np.float64(127.023443), np.float64(37.60611), np.float64(127.02747))
# 노선=100,순번=99,key=(np.float64(37.60611), np.float64(127.02747), np.float64(37.609848), np.float64(127.03204))
# 노선=100,순번=100,key=(np.float64(37.609848), np.float64(127.03204), np.float64(37.61185059), np.float64(127.03582))
# 노선=100,순번=101,key=(np.float64(37.61185059), np.float64(127.03582), np.float64(37.613712), np.float64(127.038267))
# 노선=100,순번=102,key=(np.float64(37.613712), np.float64(127.038267), np.float64(37.61785258), np.float64(127.0431131))
# 노선=100,순번=103,key=(np.float64(37.61785258), np.float64(127.0431131), np.float64(37.62031711), np.float64(127.0453451))
# 노선=100,순번=104,key=(np.float64(37.62031711), np.float64(127.0453451), np.float64(37.62356049), np.float64(127.0486035))
# 노선=100,순번=105,key=(np.float64(37.62356049), np.float64(127.0486035), np.float64(37.625218), np.float64(127.05153))
# 노선=100,순번=106,key=(np.float64(37.625218), np.float64(127.05153), np.float64(37.6290379), np.float64(127.0575128))
# 노선=100,순번=107,key=(np.float64(37.6290379), np.float64(127.0575128), np.float64(37.631739), np.float64(127.061715))
# 노선=100,순번=108,key=(np.float64(37.631739), np.float64(127.061715), np.float64(37.634055), np.float64(127.065452))
# 노선=100,순번=109,key=(np.float64(37.634055), np.float64(127.065452), np.float64(37.63492779), np.float64(127.0669625))
# 노선=100,순번=110,key=(np.float64(37.63492779), np.float64(127.0669625), np.float64(37.6365848), np.float64(127.0694328))
# 노선=100,순번=111,key=(np.float64(37.6365848), np.float64(127.0694328), np.float64(37.63727106), np.float64(127.070816))
# 노선=100,순번=112,key=(np.float64(37.63727106), np.float64(127.070816), np.float64(37.63793622), np.float64(127.0736491))
# 노선=100,순번=113,key=(np.float64(37.63793622), np.float64(127.0736491), np.float64(37.63936483), np.float64(127.074308))
# 노선=100,순번=114,key=(np.float64(37.63936483), np.float64(127.074308), np.float64(37.6420899), np.float64(127.072526))
# 노선=100,순번=115,key=(np.float64(37.6420899), np.float64(127.072526), np.float64(37.64495798), np.float64(127.0711485))
# 노선=100,순번=116,key=(np.float64(37.64495798), np.float64(127.0711485), np.float64(37.647192), np.float64(127.070212))
# 노선=100,순번=117,key=(np.float64(37.647192), np.float64(127.070212), np.float64(37.64785061), np.float64(127.0677842))
# 노선=100,순번=118,key=(np.float64(37.64785061), np.float64(127.0677842), np.float64(37.646097), np.float64(127.065243))
# 노선=100,순번=119,key=(np.float64(37.646097), np.float64(127.065243), np.float64(37.644069), np.float64(127.064373))
# 노선=100,순번=120,key=(np.float64(37.644069), np.float64(127.064373), np.float64(37.639192), np.float64(127.068945))
# 노선=100,순번=121,key=(np.float64(37.639192), np.float64(127.068945), np.float64(37.637536), np.float64(127.070635))
# 노선=101,순번=1,key=(np.float64(37.662647), np.float64(127.012719), np.float64(37.660809), np.float64(127.013424))
# 노선=101,순번=2,key=(np.float64(37.660809), np.float64(127.013424), np.float64(37.65745933), np.float64(127.0150062))
# 노선=101,순번=3,key=(np.float64(37.65745933), np.float64(127.0150062), np.float64(37.65721824), np.float64(127.0191018))
# 노선=101,순번=4,key=(np.float64(37.65721824), np.float64(127.0191018), np.float64(37.657406), np.float64(127.023049))
# 노선=101,순번=5,key=(np.float64(37.657406), np.float64(127.023049), np.float64(37.65740463), np.float64(127.0242706))
# 노선=101,순번=6,key=(np.float64(37.65740463), np.float64(127.0242706), np.float64(37.6575159), np.float64(127.0264128))
# 노선=101,순번=7,key=(np.float64(37.6575159), np.float64(127.0264128), np.float64(37.65764777), np.float64(127.0289335))
# 노선=101,순번=8,key=(np.float64(37.65764777), np.float64(127.0289335), np.float64(37.657838), np.float64(127.031452))
# 노선=101,순번=9,key=(np.float64(37.657838), np.float64(127.031452), np.float64(37.65804838), np.float64(127.034792))
# 노선=101,순번=10,key=(np.float64(37.65804838), np.float64(127.034792), np.float64(37.657248), np.float64(127.03753))
# 노선=101,순번=11,key=(np.float64(37.657248), np.float64(127.03753), np.float64(37.65455985), np.float64(127.0381737))
# 노선=101,순번=12,key=(np.float64(37.65455985), np.float64(127.0381737), np.float64(37.64881742), np.float64(127.0347687))
# 노선=101,순번=13,key=(np.float64(37.64881742), np.float64(127.0347687), np.float64(37.645293), np.float64(127.0326524))
# 노선=101,순번=14,key=(np.float64(37.645293), np.float64(127.0326524), np.float64(37.641345), np.float64(127.029165))
# 노선=101,순번=15,key=(np.float64(37.641345), np.float64(127.029165), np.float64(37.63828952), np.float64(127.0258704))
# 노선=101,순번=16,key=(np.float64(37.63828952), np.float64(127.0258704), np.float64(37.63650855), np.float64(127.0240046))
# 노선=101,순번=17,key=(np.float64(37.63650855), np.float64(127.0240046), np.float64(37.63122621), np.float64(127.024172))
# 노선=101,순번=18,key=(np.float64(37.63122621), np.float64(127.024172), np.float64(37.62486968), np.float64(127.0266493))
# 노선=101,순번=19,key=(np.float64(37.62486968), np.float64(127.0266493), np.float64(37.61971409), np.float64(127.0287194))
# 노선=101,순번=20,key=(np.float64(37.61971409), np.float64(127.0287194), np.float64(37.61376212), np.float64(127.0299325))
# 노선=101,순번=21,key=(np.float64(37.61376212), np.float64(127.0299325), np.float64(37.60588272), np.float64(127.0311379))
# 노선=101,순번=22,key=(np.float64(37.60588272), np.float64(127.0311379), np.float64(37.60143263), np.float64(127.0330444))
# 노선=101,순번=23,key=(np.float64(37.60143263), np.float64(127.0330444), np.float64(37.59941526), np.float64(127.0341075))
# 노선=101,순번=24,key=(np.float64(37.59941526), np.float64(127.0341075), np.float64(37.59480527), np.float64(127.0356812))
# 노선=101,순번=25,key=(np.float64(37.59480527), np.float64(127.0356812), np.float64(37.58856369), np.float64(127.0348108))
# 노선=101,순번=26,key=(np.float64(37.58856369), np.float64(127.0348108), np.float64(37.58513594), np.float64(127.0316105))
# 노선=101,순번=27,key=(np.float64(37.58513594), np.float64(127.0316105), np.float64(37.582482), np.float64(127.029065))
# 노선=101,순번=28,key=(np.float64(37.582482), np.float64(127.029065), np.float64(37.57970665), np.float64(127.0250277))
# 노선=101,순번=29,key=(np.float64(37.57970665), np.float64(127.0250277), np.float64(37.57569473), np.float64(127.0228414))
# 노선=101,순번=30,key=(np.float64(37.57569473), np.float64(127.0228414), np.float64(37.57424646), np.float64(127.0195528))
# 노선=101,순번=31,key=(np.float64(37.57424646), np.float64(127.0195528), np.float64(37.57215245), np.float64(127.0124191))
# 노선=101,순번=32,key=(np.float64(37.57215245), np.float64(127.0124191), np.float64(37.57112723), np.float64(127.0057137))
# 노선=101,순번=33,key=(np.float64(37.57112723), np.float64(127.0057137), np.float64(37.570931), np.float64(126.999606))
# 노선=101,순번=34,key=(np.float64(37.570931), np.float64(126.999606), np.float64(37.570637), np.float64(126.995396))
# 노선=101,순번=35,key=(np.float64(37.570637), np.float64(126.995396), np.float64(37.57036054), np.float64(126.9899878))
# 노선=101,순번=36,key=(np.float64(37.57036054), np.float64(126.9899878), np.float64(37.570238), np.float64(126.986536))
# 노선=101,순번=37,key=(np.float64(37.570238), np.float64(126.986536), np.float64(37.570271), np.float64(126.98163))
# 노선=101,순번=38,key=(np.float64(37.570271), np.float64(126.98163), np.float64(37.57023966), np.float64(126.9778803))
# 노선=101,순번=39,key=(np.float64(37.57023966), np.float64(126.9778803), np.float64(37.570023), np.float64(126.971248))
# 노선=101,순번=40,key=(np.float64(37.570023), np.float64(126.971248), np.float64(37.56814593), np.float64(126.9686005))
# ...
# 노선=6613,순번=37,key=(np.float64(37.49350098), np.float64(126.8943735), np.float64(37.491138), np.float64(126.893798))
# 노선=6613,순번=38,key=(np.float64(37.491138), np.float64(126.893798), np.float64(37.49309315), np.float64(126.8908083))
# 노선=6613,순번=39,key=(np.float64(37.49309315), np.float64(126.8908083), np.float64(37.49475088), np.float64(126.8876042))
# 노선=6613,순번=40,key=(np.float64(37.49475088), np.float64(126.8876042), np.float64(37.49378426), np.float64(126.8832313))
# 노선=6613,순번=41,key=(np.float64(37.49378426), np.float64(126.8832313), np.float64(37.49778869), np.float64(126.8840767))
# 노선=6613,순번=42,key=(np.float64(37.49778869), np.float64(126.8840767), np.float64(37.49982279), np.float64(126.8834798))
# 노선=6613,순번=43,key=(np.float64(37.49982279), np.float64(126.8834798), np.float64(37.50356809), np.float64(126.8793093))
# 노선=6613,순번=44,key=(np.float64(37.50356809), np.float64(126.8793093), np.float64(37.50516558), np.float64(126.877402))
# 노선=6613,순번=45,key=(np.float64(37.50516558), np.float64(126.877402), np.float64(37.511285), np.float64(126.869212))
# 노선=6613,순번=46,key=(np.float64(37.511285), np.float64(126.869212), np.float64(37.51033), np.float64(126.866702))
# 노선=6613,순번=47,key=(np.float64(37.51033), np.float64(126.866702), np.float64(37.50817426), np.float64(126.8633495))
# 노선=6613,순번=48,key=(np.float64(37.50817426), np.float64(126.8633495), np.float64(37.50739076), np.float64(126.8614269))
# 노선=6613,순번=49,key=(np.float64(37.50739076), np.float64(126.8614269), np.float64(37.50615802), np.float64(126.8583582))
# 노선=6613,순번=50,key=(np.float64(37.50615802), np.float64(126.8583582), np.float64(37.50463373), np.float64(126.8544694))
# 노선=6613,순번=51,key=(np.float64(37.50463373), np.float64(126.8544694), np.float64(37.50318205), np.float64(126.850607))
# 노선=6613,순번=52,key=(np.float64(37.50318205), np.float64(126.850607), np.float64(37.50112329), np.float64(126.850809))
# 노선=6613,순번=53,key=(np.float64(37.50112329), np.float64(126.850809), np.float64(37.49900153), np.float64(126.851795))
# 노선=6613,순번=54,key=(np.float64(37.49900153), np.float64(126.851795), np.float64(37.49652412), np.float64(126.844586))
# 노선=6613,순번=55,key=(np.float64(37.49652412), np.float64(126.844586), np.float64(37.49560231), np.float64(126.842537))
# 노선=6613,순번=56,key=(np.float64(37.49560231), np.float64(126.842537), np.float64(37.49426454), np.float64(126.8394648))
# 노선=6613,순번=57,key=(np.float64(37.49426454), np.float64(126.8394648), np.float64(37.49330279), np.float64(126.8359814))
# 노선=6613,순번=58,key=(np.float64(37.49330279), np.float64(126.8359814), np.float64(37.49345532), np.float64(126.8342168))
# 노선=6613,순번=59,key=(np.float64(37.49345532), np.float64(126.8342168), np.float64(37.49532), np.float64(126.831304))
# 노선=6613,순번=60,key=(np.float64(37.49532), np.float64(126.831304), np.float64(37.496815), np.float64(126.829596))
# 노선=6613,순번=61,key=(np.float64(37.496815), np.float64(126.829596), np.float64(37.498605), np.float64(126.829242))
# 노선=6613,순번=62,key=(np.float64(37.498605), np.float64(126.829242), np.float64(37.50055659), np.float64(126.8295257))
# 노선=6613,순번=63,key=(np.float64(37.50055659), np.float64(126.8295257), np.float64(37.4984), np.float64(126.82904))
# 노선=6613,순번=64,key=(np.float64(37.4984), np.float64(126.82904), np.float64(37.49678424), np.float64(126.8293339))
# 노선=6613,순번=65,key=(np.float64(37.49678424), np.float64(126.8293339), np.float64(37.494359), np.float64(126.830852))
# 노선=6613,순번=66,key=(np.float64(37.494359), np.float64(126.830852), np.float64(37.4933), np.float64(126.830847))
# 노선=6613,순번=67,key=(np.float64(37.4933), np.float64(126.830847), np.float64(37.49604407), np.float64(126.824903))
# 노선=6613,순번=68,key=(np.float64(37.49604407), np.float64(126.824903), np.float64(37.49697459), np.float64(126.8221461))
# 노선=6613,순번=69,key=(np.float64(37.49697459), np.float64(126.8221461), np.float64(37.49605595), np.float64(126.8243872))
# 노선=6613,순번=70,key=(np.float64(37.49605595), np.float64(126.8243872), np.float64(37.495086), np.float64(126.825715))
# 노선=6613,순번=71,key=(np.float64(37.495086), np.float64(126.825715), np.float64(37.49282656), np.float64(126.8238226))
# 노선=6613,순번=72,key=(np.float64(37.49282656), np.float64(126.8238226), np.float64(37.491968), np.float64(126.82122))
# 노선=6613,순번=73,key=(np.float64(37.491968), np.float64(126.82122), np.float64(37.49277702), np.float64(126.8244009))
# 노선=6613,순번=74,key=(np.float64(37.49277702), np.float64(126.8244009), np.float64(37.4930634), np.float64(126.8304506))
# 노선=6613,순번=75,key=(np.float64(37.4930634), np.float64(126.8304506), np.float64(37.494651), np.float64(126.830866))
# 노선=6613,순번=76,key=(np.float64(37.494651), np.float64(126.830866), np.float64(37.496815), np.float64(126.829596))
# 노선=6613,순번=77,key=(np.float64(37.496815), np.float64(126.829596), np.float64(37.498605), np.float64(126.829242))
# 노선=6613,순번=78,key=(np.float64(37.498605), np.float64(126.829242), np.float64(37.502207), np.float64(126.829187))
# 노선=6613,순번=79,key=(np.float64(37.502207), np.float64(126.829187), np.float64(37.506447), np.float64(126.834138))
# 노선=6613,순번=80,key=(np.float64(37.506447), np.float64(126.834138), np.float64(37.50849276), np.float64(126.8372191))
# 노선=6614,순번=1,key=(np.float64(37.508701), np.float64(126.837646), np.float64(37.514504), np.float64(126.830539))
# 노선=6614,순번=2,key=(np.float64(37.514504), np.float64(126.830539), np.float64(37.513244), np.float64(126.828913))
# 노선=6614,순번=3,key=(np.float64(37.513244), np.float64(126.828913), np.float64(37.511293), np.float64(126.83046))
# 노선=6614,순번=4,key=(np.float64(37.511293), np.float64(126.83046), np.float64(37.511199), np.float64(126.833468))
# 노선=6614,순번=5,key=(np.float64(37.511199), np.float64(126.833468), np.float64(37.51265311), np.float64(126.8353881))
# 노선=6614,순번=6,key=(np.float64(37.51265311), np.float64(126.8353881), np.float64(37.51419128), np.float64(126.8340906))
# 노선=6614,순번=7,key=(np.float64(37.51419128), np.float64(126.8340906), np.float64(37.515731), np.float64(126.83553))
# 노선=6614,순번=8,key=(np.float64(37.515731), np.float64(126.83553), np.float64(37.51635995), np.float64(126.8377839))
# 노선=6614,순번=9,key=(np.float64(37.51635995), np.float64(126.8377839), np.float64(37.51782796), np.float64(126.8418635))
# 노선=6614,순번=10,key=(np.float64(37.51782796), np.float64(126.8418635), np.float64(37.51928494), np.float64(126.8438199))
# 노선=6614,순번=11,key=(np.float64(37.51928494), np.float64(126.8438199), np.float64(37.52142649), np.float64(126.8462897))
# 노선=6614,순번=12,key=(np.float64(37.52142649), np.float64(126.8462897), np.float64(37.5220233), np.float64(126.8507301))
# 노선=6614,순번=13,key=(np.float64(37.5220233), np.float64(126.8507301), np.float64(37.52247391), np.float64(126.8518789))
# 노선=6614,순번=14,key=(np.float64(37.52247391), np.float64(126.8518789), np.float64(37.52463013), np.float64(126.8542989))
# 노선=6614,순번=15,key=(np.float64(37.52463013), np.float64(126.8542989), np.float64(37.52539572), np.float64(126.8599725))
# 노선=6614,순번=16,key=(np.float64(37.52539572), np.float64(126.8599725), np.float64(37.52580579), np.float64(126.8631069))
# 노선=6614,순번=17,key=(np.float64(37.52580579), np.float64(126.8631069), np.float64(37.52450719), np.float64(126.8645744))
# 노선=6614,순번=18,key=(np.float64(37.52450719), np.float64(126.8645744), np.float64(37.52179), np.float64(126.865547))
# 노선=6614,순번=19,key=(np.float64(37.52179), np.float64(126.865547), np.float64(37.514267), np.float64(126.869395))
# 노선=6614,순번=20,key=(np.float64(37.514267), np.float64(126.869395), np.float64(37.51256669), np.float64(126.8653279))
# 노선=6614,순번=21,key=(np.float64(37.51256669), np.float64(126.8653279), np.float64(37.511505), np.float64(126.862188))
# 노선=6614,순번=22,key=(np.float64(37.511505), np.float64(126.862188), np.float64(37.510413), np.float64(126.859079))
# 노선=6614,순번=23,key=(np.float64(37.510413), np.float64(126.859079), np.float64(37.513032), np.float64(126.853865))
# 노선=6614,순번=24,key=(np.float64(37.513032), np.float64(126.853865), np.float64(37.51166135), np.float64(126.8498548))
# 노선=6614,순번=25,key=(np.float64(37.51166135), np.float64(126.8498548), np.float64(37.50985233), np.float64(126.8445827))
# 노선=6614,순번=26,key=(np.float64(37.50985233), np.float64(126.8445827), np.float64(37.5083598), np.float64(126.8429841))
# 노선=6614,순번=27,key=(np.float64(37.5083598), np.float64(126.8429841), np.float64(37.50046951), np.float64(126.8469151))
# 노선=6614,순번=28,key=(np.float64(37.50046951), np.float64(126.8469151), np.float64(37.49652412), np.float64(126.844586))
# 노선=6614,순번=29,key=(np.float64(37.49652412), np.float64(126.844586), np.float64(37.49560231), np.float64(126.842537))
# 노선=6614,순번=30,key=(np.float64(37.49560231), np.float64(126.842537), np.float64(37.49426454), np.float64(126.8394648))
# 노선=6614,순번=31,key=(np.float64(37.49426454), np.float64(126.8394648), np.float64(37.491563), np.float64(126.8316708))
# 노선=6614,순번=32,key=(np.float64(37.491563), np.float64(126.8316708), np.float64(37.488482), np.float64(126.824599))
# 노선=6614,순번=33,key=(np.float64(37.488482), np.float64(126.824599), np.float64(37.48726514), np.float64(126.8239106))
# 노선=6614,순번=34,key=(np.float64(37.48726514), np.float64(126.8239106), np.float64(37.486043), np.float64(126.823435))
# 노선=6614,순번=35,key=(np.float64(37.486043), np.float64(126.823435), np.float64(37.48428958), np.float64(126.8224245))
# 노선=6614,순번=36,key=(np.float64(37.48428958), np.float64(126.8224245), np.float64(37.48108359), np.float64(126.8216009))
# 노선=6614,순번=37,key=(np.float64(37.48108359), np.float64(126.8216009), np.float64(37.47874661), np.float64(126.8229434))
# 노선=6614,순번=38,key=(np.float64(37.47874661), np.float64(126.8229434), np.float64(37.476655), np.float64(126.823154))
# 노선=6614,순번=39,key=(np.float64(37.476655), np.float64(126.823154), np.float64(37.47465326), np.float64(126.823943))
# 노선=6614,순번=40,key=(np.float64(37.47465326), np.float64(126.823943), np.float64(37.47327519), np.float64(126.8245407))
# 노선=6614,순번=41,key=(np.float64(37.47327519), np.float64(126.8245407), np.float64(37.47190772), np.float64(126.8258443))
# 노선=6614,순번=42,key=(np.float64(37.47190772), np.float64(126.8258443), np.float64(37.46702503), np.float64(126.8249063))
# 노선=6614,순번=43,key=(np.float64(37.46702503), np.float64(126.8249063), np.float64(37.46589362), np.float64(126.827325))
# 노선=6614,순번=44,key=(np.float64(37.46589362), np.float64(126.827325), np.float64(37.46357928), np.float64(126.8274987))
# 노선=6614,순번=45,key=(np.float64(37.46357928), np.float64(126.8274987), np.float64(37.46166099), np.float64(126.8259788))
# 노선=6614,순번=46,key=(np.float64(37.46166099), np.float64(126.8259788), np.float64(37.46126237), np.float64(126.8202146))
# 노선=6614,순번=47,key=(np.float64(37.46126237), np.float64(126.8202146), np.float64(37.46497987), np.float64(126.8208941))
# 노선=6614,순번=48,key=(np.float64(37.46497987), np.float64(126.8208941), np.float64(37.46732981), np.float64(126.8226178))
# 노선=6614,순번=49,key=(np.float64(37.46732981), np.float64(126.8226178), np.float64(37.47204685), np.float64(126.8257986))
# 노선=6614,순번=50,key=(np.float64(37.47204685), np.float64(126.8257986), np.float64(37.47316724), np.float64(126.8248324))
# 노선=6614,순번=51,key=(np.float64(37.47316724), np.float64(126.8248324), np.float64(37.47480825), np.float64(126.8239528))
# 노선=6614,순번=52,key=(np.float64(37.47480825), np.float64(126.8239528), np.float64(37.476712), np.float64(126.82332))
# 노선=6614,순번=53,key=(np.float64(37.476712), np.float64(126.82332), np.float64(37.47916111), np.float64(126.8230451))
# 노선=6614,순번=54,key=(np.float64(37.47916111), np.float64(126.8230451), np.float64(37.4812765), np.float64(126.821657))
# 노선=6614,순번=55,key=(np.float64(37.4812765), np.float64(126.821657), np.float64(37.483782), np.float64(126.822295))
# 노선=6614,순번=56,key=(np.float64(37.483782), np.float64(126.822295), np.float64(37.4858461), np.float64(126.8234379))
# 노선=6614,순번=57,key=(np.float64(37.4858461), np.float64(126.8234379), np.float64(37.48719856), np.float64(126.8239763))
# 노선=6614,순번=58,key=(np.float64(37.48719856), np.float64(126.8239763), np.float64(37.48944695), np.float64(126.8250439))
# 노선=6614,순번=59,key=(np.float64(37.48944695), np.float64(126.8250439), np.float64(37.49120294), np.float64(126.8311076))
# 노선=6614,순번=60,key=(np.float64(37.49120294), np.float64(126.8311076), np.float64(37.494463), np.float64(126.840682))
# 노선=6614,순번=61,key=(np.float64(37.494463), np.float64(126.840682), np.float64(37.495698), np.float64(126.843351))
# 노선=6614,순번=62,key=(np.float64(37.495698), np.float64(126.843351), np.float64(37.49683797), np.float64(126.8461421))
# 노선=6614,순번=63,key=(np.float64(37.49683797), np.float64(126.8461421), np.float64(37.501413), np.float64(126.846791))
# 노선=6614,순번=64,key=(np.float64(37.501413), np.float64(126.846791), np.float64(37.50742085), np.float64(126.8439634))
# 노선=6614,순번=65,key=(np.float64(37.50742085), np.float64(126.8439634), np.float64(37.50992673), np.float64(126.8456572))
# 노선=6614,순번=66,key=(np.float64(37.50992673), np.float64(126.8456572), np.float64(37.51157732), np.float64(126.8503821))
# 노선=6614,순번=67,key=(np.float64(37.51157732), np.float64(126.8503821), np.float64(37.5129), np.float64(126.854138))
# 노선=6614,순번=68,key=(np.float64(37.5129), np.float64(126.854138), np.float64(37.51311521), np.float64(126.8559491))
# 노선=6614,순번=69,key=(np.float64(37.51311521), np.float64(126.8559491), np.float64(37.510288), np.float64(126.85918))
# 노선=6614,순번=70,key=(np.float64(37.510288), np.float64(126.85918), np.float64(37.51171675), np.float64(126.863621))
# 노선=6614,순번=71,key=(np.float64(37.51171675), np.float64(126.863621), np.float64(37.512871), np.float64(126.866609))
# 노선=6614,순번=72,key=(np.float64(37.512871), np.float64(126.866609), np.float64(37.5218496), np.float64(126.8659323))
# 노선=6614,순번=73,key=(np.float64(37.5218496), np.float64(126.8659323), np.float64(37.52394011), np.float64(126.8651038))
# 노선=6614,순번=74,key=(np.float64(37.52394011), np.float64(126.8651038), np.float64(37.52595861), np.float64(126.862791))
# 노선=6614,순번=75,key=(np.float64(37.52595861), np.float64(126.862791), np.float64(37.52565303), np.float64(126.8603986))
# 노선=6614,순번=76,key=(np.float64(37.52565303), np.float64(126.8603986), np.float64(37.52486371), np.float64(126.853972))
# 노선=6614,순번=77,key=(np.float64(37.52486371), np.float64(126.853972), np.float64(37.523082), np.float64(126.851248))
# 노선=6614,순번=78,key=(np.float64(37.523082), np.float64(126.851248), np.float64(37.52188642), np.float64(126.8515144))
# 노선=6614,순번=79,key=(np.float64(37.52188642), np.float64(126.8515144), np.float64(37.52188249), np.float64(126.8463249))
# 노선=6614,순번=80,key=(np.float64(37.52188249), np.float64(126.8463249), np.float64(37.51964347), np.float64(126.8437433))
# 노선=6614,순번=81,key=(np.float64(37.51964347), np.float64(126.8437433), np.float64(37.518022), np.float64(126.841605))
# 노선=6614,순번=82,key=(np.float64(37.518022), np.float64(126.841605), np.float64(37.51669255), np.float64(126.8378579))
# 노선=6614,순번=83,key=(np.float64(37.51669255), np.float64(126.8378579), np.float64(37.515937), np.float64(126.835305))
# 노선=6614,순번=84,key=(np.float64(37.515937), np.float64(126.835305), np.float64(37.514504), np.float64(126.830539))
# 노선=6614,순번=85,key=(np.float64(37.514504), np.float64(126.830539), np.float64(37.513244), np.float64(126.828913))
# 노선=6614,순번=86,key=(np.float64(37.513244), np.float64(126.828913), np.float64(37.511293), np.float64(126.83046))
# 노선=6614,순번=87,key=(np.float64(37.511293), np.float64(126.83046), np.float64(37.511199), np.float64(126.833468))
# 노선=6614,순번=88,key=(np.float64(37.511199), np.float64(126.833468), np.float64(37.511319), np.float64(126.835885))
# 노선=6614,순번=89,key=(np.float64(37.511319), np.float64(126.835885), np.float64(37.50849276), np.float64(126.8372191))
# 노선별 거리 계산 진행:  58%|████████████████████████████████████████████████████████▏                                        | 408/705 [00:00<00:00, 508.77it/s]IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
src_df = src_df.sort_values(by=['노선명', '순번'])

# %%
src_df
# Out:
#        ROUTE_ID     노선명  순번    NODE_ID  ARS_ID         정류소명         X좌표  \
# 720   100100124    0017   2  102000158    3252      신용산지하차도  126.963882
# 1663  100100124    0017   3  102000161    3255          용산역  126.965822
# 2683  100100124    0017   4  102000162    3256     용산푸르지오써밋  126.964759
# 3254  100100124    0017   5  102000029    3122       한강대교북단  126.963570
# 3534  100100124    0017   6  102000200    3294      서부이촌동입구  126.959497
# ...         ...     ...  ..        ...     ...          ...         ...
# 832   100000020  청와대A01   2  100000415    1119          영추문  126.973982
# 2061  100000020  청와대A01   3  100000416    1601          청와대  126.973762
# 2767  100000020  청와대A01   4  100000417    1602          춘추문  126.979657
# 3474  100000020  청와대A01   5  100000418    1603  경복궁.국립민속박물관  126.979590
# 3564  100000020  청와대A01   6  100000420    1604    효자로입구(가상)  126.974433
#
#             Y좌표      시    구      동   거리
# 720   37.532590  서울특별시  용산구  한강로3가  0.0
# 1663  37.528869  서울특별시  용산구  한강로3가  0.0
# 2683  37.527574  서울특별시  용산구  한강로3가  0.0
# 3254  37.524968  서울특별시  용산구  한강로3가  0.0
# 3534  37.523863  서울특별시  용산구  한강로3가  0.0
# ...         ...    ...  ...    ...  ...
# 832   37.578930  서울특별시  종로구    세종로  0.0
# 2061  37.582971  서울특별시  종로구    세종로  0.0
# 2767  37.583126  서울특별시  종로구    팔판동  0.0
# 3474  37.579407  서울특별시  종로구    세종로  0.0
# 3564  37.576265  서울특별시  종로구    세종로  0.0
#
# [41261 rows x 12 columns]

# %%
import pickle

def load_cache_from_pickle(filename):
  try:
    with open(filename, 'rb') as f: # 'rb'는 Read Binary 모드
      loaded_cache = pickle.load(f)
    print(f"캐시를 '{filename}'에서 성공적으로 불러왔습니다.")
    return loaded_cache
  except FileNotFoundError:
    print(f"경고: '{filename}' 파일을 찾을 수 없습니다. 빈 캐시를 반환합니다.")
    return []

# %%
DISTANCE_CACHE_LOADED = load_cache_from_pickle("20251027_DISTANCE_CACHE.pkl")
# Out:
# 캐시를 '20251015_DISTANCE_CACHE.pkl'에서 성공적으로 불러왔습니다.

# %%
print(f"len={len(DISTANCE_CACHE_LOADED)}")
# Out:
# len17229

# %%
echo_route_df = src_df[src_df['노선명'] == '0017']

# %%
echo_route_df
# Out:
#         ROUTE_ID   노선명  순번    NODE_ID  ARS_ID             정류소명         X좌표  \
# 720    100100124  0017   2  102000158    3252          신용산지하차도  126.963882
# 1663   100100124  0017   3  102000161    3255              용산역  126.965822
# 2683   100100124  0017   4  102000162    3256         용산푸르지오써밋  126.964759
# 3254   100100124  0017   5  102000029    3122           한강대교북단  126.963570
# 3534   100100124  0017   6  102000200    3294          서부이촌동입구  126.959497
# 4655   100100124  0017   7  102000198    3292  이촌2동대림아파트.새남터성지  126.956323
# 5258   100100124  0017   8  102000196    3290         이촌2동주민센터  126.955064
# 5945   100100124  0017   9  102000194    3288     성촌공원.포르쉐센터용산  126.954606
# 6671   100100124  0017  10  102000193    3287   이촌119안전센터.성촌공원  126.952943
# 7337   100100124  0017  11  102000202    3296      원효2동산호아파트후문  126.950016
# 7787   100100124  0017  12  102000204    3298       청암동강변삼성아파트  126.949323
# 8671   100100124  0017  13  102000227    3321            청심경로당  126.950688
# 9434   100100124  0017  14  102000210    3304         원효2동주민센터  126.951395
# 9984   100100124  0017  15  102000212    3306      산천동.성심여중고후문  126.953643
# 10626  100100124  0017  16  102000214    3308         신창동세방아파트  126.954955
# 11377  100100124  0017  17  102000216    3310           남이장군사당  126.957822
# 12009  100100124  0017  18  102000218    3312    용문시장.용문동새마을금고  126.959534
# 12296  100100124  0017  19  102000153    3247             용문시장  126.960969
# 13245  100100124  0017  20  102000156    3250         용산전자상가입구  126.961938
# 13864  100100124  0017  21  102000158    3252          신용산지하차도  126.963882
# 14351  100100124  0017  22  102000026    3119         신용산역3번출구  126.967351
# 14742  100100124  0017  23  102000157    3251          신용산지하차도  126.963668
# 15618  100100124  0017  24  102000155    3249         용산전자상가입구  126.962222
# 15934  100100124  0017  25  102000154    3248             용문시장  126.961360
# 16751  100100124  0017  26  102000219    3313    용문시장.용문동새마을금고  126.959197
# 17281  100100124  0017  27  102000217    3311           남이장군사당  126.957703
# 17643  100100124  0017  28  102000215    3309         신창동세방아파트  126.954947
# 18436  100100124  0017  29  102000213    3307      산천동.성심여중고후문  126.953382
# 18950  100100124  0017  30  102000211    3305      산천동리버힐삼성아파트  126.951192
# 19439  100100124  0017  31  102000228    3322            삼성테마트  126.950385
# 19685  100100124  0017  32  102000205    3299        원효2동산호아파트  126.950542
# 20198  100100124  0017  33  102000207    3301         원효로풍전아파트  126.953523
# 21082  100100124  0017  34  102000195    3289     성촌공원.포르쉐센터용산  126.954351
# 21362  100100124  0017  35  102000197    3291         이촌2동주민센터  126.954862
# 21813  100100124  0017  36  102000199    3293  이촌2동대림아파트.새남터성지  126.956166
# 22090  100100124  0017  37  102000201    3295        이촌2동강변아파트  126.959781
# 22670  100100124  0017  38  102000001    3001    한강대교북단.LG유플러스  126.963121
# 22940  100100124  0017  39  102000003    3003             신용산역  126.966207
# 23540  100100124  0017  40  102000159    3253         신용산역5번출구  126.967679
# 24113  100100124  0017  41  102000318    3121    용산역3번출구.용산차고지  126.964215
#
#              Y좌표      시    구      동   거리
# 720    37.532590  서울특별시  용산구  한강로3가  0.0
# 1663   37.528869  서울특별시  용산구  한강로3가  0.0
# 2683   37.527574  서울특별시  용산구  한강로3가  0.0
# 3254   37.524968  서울특별시  용산구  한강로3가  0.0
# 3534   37.523863  서울특별시  용산구  한강로3가  0.0
# 4655   37.526175  서울특별시  용산구    이촌동  0.0
# 5258   37.527736  서울특별시  용산구  한강로3가  0.0
# 5945   37.530171  서울특별시  용산구  한강로3가  0.0
# 6671   37.530082  서울특별시  용산구    이촌동  0.0
# 7337   37.532260  서울특별시  용산구  원효로4가  0.0
# 7787   37.534015  서울특별시  용산구  원효로4가  0.0
# 8671   37.533887  서울특별시  용산구    산천동  0.0
# 9434   37.534494  서울특별시  용산구    산천동  0.0
# 9984   37.535320  서울특별시  용산구    신창동  0.0
# 10626  37.535708  서울특별시  용산구    신창동  0.0
# 11377  37.536608  서울특별시  용산구    용문동  0.0
# 12009  37.537072  서울특별시  용산구    용문동  0.0
# 12296  37.536348  서울특별시  용산구    용문동  0.0
# 13245  37.534658  서울특별시  용산구  원효로2가  0.0
# 13864  37.532590  서울특별시  용산구  한강로3가  0.0
# 14351  37.528889  서울특별시  용산구  한강로2가  0.0
# 14742  37.532835  서울특별시  용산구  한강로3가  0.0
# 15618  37.534570  서울특별시  용산구    신계동  0.0
# 15934  37.535979  서울특별시  용산구  원효로2가  0.0
# 16751  37.537149  서울특별시  용산구    용문동  0.0
# 17281  37.536824  서울특별시  용산구    용문동  0.0
# 17643  37.535830  서울특별시  용산구    신창동  0.0
# 18436  37.535408  서울특별시  용산구    신창동  0.0
# 18950  37.534500  서울특별시  용산구    산천동  0.0
# 19439  37.533747  서울특별시  용산구  원효로4가  0.0
# 19685  37.533018  서울특별시  용산구  원효로4가  0.0
# 20198  37.532129  서울특별시  용산구  원효로4가  0.0
# 21082  37.529747  서울특별시  용산구    이촌동  0.0
# 21362  37.527703  서울특별시  용산구    이촌동  0.0
# 21813  37.526029  서울특별시  용산구    이촌동  0.0
# 22090  37.523446  서울특별시  용산구    이촌동  0.0
# 22670  37.524049  서울특별시  용산구  한강로3가  0.0
# 22940  37.527293  서울특별시  용산구  한강로2가  0.0
# 23540  37.530034  서울특별시  용산구  한강로2가  0.0
# 24113  37.531808  서울특별시  용산구  한강로3가  0.0

# %%
bus_list = []

# %%
def check_in_cache(cached, bus_no):
    org_df = globals()['src_df']

    each_route_df = org_df[org_df['노선명'] == bus_no]

    original_indices = each_route_df.index

    for i in range(len(original_indices) - 1):
        idx1 = original_indices[i]
        idx2 = original_indices[i+1]    

        lat1 = org_df.loc[idx1, 'Y좌표']
        lon1 = org_df.loc[idx1, 'X좌표']
        lat2 = org_df.loc[idx2, 'Y좌표']
        lon2 = org_df.loc[idx2, 'X좌표']

        cache_key = (lat1, lon1, lat2, lon2)
        
        if cache_key in cached:
            distance = cached[cache_key]
            #print("cache hit!!", distance)
            
            org_df.loc[idx1, '거리'] = distance
        else:
            print(f"bus_no={bus_no},not in cache idx={i}")
            globals()['bus_list'].append(bus_no)
            return

    #print(org_df[org_df['노선명'] == bus_no])

# %%
grouped = src_df.groupby('노선명')

  # 각 노선별로 순회하며 거리 계산
for route_name, route_df in tqdm(grouped, desc="노선별 거리 계산 진행", total=len(grouped)):
    #print(f"route_name={route_name}")
    check_in_cache(DISTANCE_CACHE_LOADED, route_name)
# Out:
# 노선별 거리 계산 진행:   0%|                                                                                                            | 0/705 [00:00<?, ?it/s]
# 노선별 거리 계산 진행:  17%|████████████████▎                                                                                | 119/705 [00:00<00:04, 123.53it/s]
# bus_no=2412,not in cache idx=47
# 노선별 거리 계산 진행:  23%|██████████████████████▌                                                                          | 164/705 [00:01<00:03, 138.74it/s]
# bus_no=3416,not in cache idx=39
# bus_no=3426,not in cache idx=12
# bus_no=361,not in cache idx=9
# bus_no=402,not in cache idx=11
# bus_no=4425,not in cache idx=38
# 노선별 거리 계산 진행:  30%|████████████████████████████▊                                                                    | 209/705 [00:01<00:03, 145.66it/s]
# bus_no=500,not in cache idx=12
# bus_no=504,not in cache idx=24
# bus_no=5525,not in cache idx=19
# bus_no=5535,not in cache idx=20
# 노선별 거리 계산 진행:  37%|███████████████████████████████████▍                                                             | 258/705 [00:01<00:02, 152.94it/s]
# bus_no=6001,not in cache idx=52
# bus_no=6005,not in cache idx=49
# bus_no=6006,not in cache idx=18
# bus_no=6007,not in cache idx=35
# bus_no=6008,not in cache idx=17
# bus_no=6009,not in cache idx=27
# bus_no=6013,not in cache idx=55
# bus_no=6016,not in cache idx=20
# bus_no=6017,not in cache idx=50
# bus_no=6019,not in cache idx=51
# bus_no=6020,not in cache idx=17
# bus_no=6103,not in cache idx=14
# bus_no=6200,not in cache idx=25
# bus_no=6300,not in cache idx=31
# 노선별 거리 계산 진행:  44%|██████████████████████████████████████████▏                                                      | 307/705 [00:02<00:02, 151.89it/s]
# bus_no=6600,not in cache idx=25
# bus_no=6703,not in cache idx=40
# bus_no=6705A,not in cache idx=45
# 노선별 거리 계산 진행:  65%|██████████████████████████████████████████████████████████████▉                                  | 457/705 [00:03<00:01, 176.05it/s]
# bus_no=N6703,not in cache idx=33
# bus_no=강남03,not in cache idx=22
# bus_no=강남06,not in cache idx=10
# bus_no=강남06-1,not in cache idx=9
# bus_no=강남06-2,not in cache idx=9
# 노선별 거리 계산 진행:  92%|████████████████████████████████████████████████████████████████████████████████████████▉        | 646/705 [00:03<00:00, 299.73it/s]
# bus_no=서초06,not in cache idx=4
# bus_no=서초16,not in cache idx=16
# bus_no=서초17,not in cache idx=36
# 노선별 거리 계산 진행: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 705/705 [00:03<00:00, 178.42it/s]

# %%
bus_list
# Out:
# ['2412',
#  '3416',
#  '3426',
#  '361',
#  '402',
#  '4425',
#  '500',
#  '504',
#  '5525',
#  '5535',
#  '6001',
#  '6005',
#  '6006',
#  '6007',
#  '6008',
#  '6009',
#  '6013',
#  '6016',
#  '6017',
#  '6019',
#  '6020',
#  '6103',
#  '6200',
#  '6300',
#  '6600',
#  '6703',
#  '6705A',
#  'N6703',
#  '강남03',
#  '강남06',
#  '강남06-1',
#  '강남06-2',
#  '서초06',
#  '서초16',
#  '서초17']

# %%
print(f"'특정컬럼'의 값이 0.0인 행의 개수: {(src_df['거리'] == 0.0).sum()}")
# Out:
# '특정컬럼'의 값이 0.0인 행의 개수: 1875

# %%
src_df[src_df['노선명'] == '3416']
# Out:
#         ROUTE_ID   노선명  순번    NODE_ID  ARS_ID            정류소명         X좌표  \
# 66     100100228  3416   1  123000337   24429          남한산성입구  127.157278
# 1038   100100228  3416   2  123000200   24290     송파구립마천청소년센터  127.156790
# 1841   100100228  3416   3  123000201   24291  송파보훈회관.금호어울림2차  127.155809
# 2560   100100228  3416   4  123000203   24293   마천동금호어울림1차아파트  127.154198
# 3237   100100228  3416   5  123000206   24296  남천초교.마천동우방아파트앞  127.151931
# ...          ...   ...  ..        ...     ...             ...         ...
# 31250  100100228  3416  61  123000205   24295  마천시장.마천동우방아파트앞  127.151510
# 31561  100100228  3416  62  123000204   24294   마천동금호어울림1차아파트  127.154075
# 31862  100100228  3416  63  123000202   24292  송파보훈회관.금호어울림2차  127.155567
# 32149  100100228  3416  64  123000199   24289     송파구립마천청소년센터  127.156552
# 32435  100100228  3416  65  123000198   24288          남한산성입구  127.157155
#
#              Y좌표      시    구    동     거리
# 66     37.490960  서울특별시  송파구  마천동  115.0
# 1038   37.491832  서울특별시  송파구  마천동  551.0
# 1841   37.493968  서울특별시  송파구  마천동  396.0
# 2560   37.497198  서울특별시  송파구  마천동  434.0
# 3237   37.499919  서울특별시  송파구  마천동  209.0
# ...          ...    ...  ...  ...    ...
# 31250  37.499937  서울특별시  송파구  마천동  378.0
# 31561  37.497978  서울특별시  송파구  마천동  473.0
# 31862  37.493992  서울특별시  송파구  마천동  239.0
# 32149  37.491982  서울특별시  송파구  마천동  140.0
# 32435  37.490972  서울특별시  송파구  마천동    0.0
#
# [65 rows x 12 columns]

# %%
def check_distance(cached, bus_no):
    org_df = globals()['src_df']

    each_route_df = org_df[org_df['노선명'] == bus_no]

    sums = (each_route_df['거리'] == 0.0).sum()

    if sums == 0:
        print(f"bus={bus_no} is done.")
        return

    original_indices = each_route_df.index

    for i in range(len(original_indices) - 1):
        idx1 = original_indices[i]
        idx2 = original_indices[i+1]  

        if org_df.loc[idx1, '거리'] == 0.0:
            print(f"bus={bus_no},idx={i} ==> break")

            lat1 = org_df.loc[idx1, 'Y좌표']
            lon1 = org_df.loc[idx1, 'X좌표']
            lat2 = org_df.loc[idx2, 'Y좌표']
            lon2 = org_df.loc[idx2, 'X좌표']

            new_distance = calcDistanceByApi(lon1, lat1, lon2, lat2)

            cache_key = (lat1, lon1, lat2, lon2)
                
            is_numeric = isinstance(new_distance, (int, float))
    
            if is_numeric and not np.isnan(new_distance):
                cached[cache_key] = new_distance
                org_df.loc[idx1, '거리'] = new_distance

            return

# %%
for x in range(len(bus_list)):
    for i in range(50):
        check_distance(DISTANCE_CACHE_LOADED, bus_list[x])
# Out:
# bus=3426,idx=62 ==> break
# bus=3426,idx=63 ==> break
# bus=3426,idx=64 ==> break
# bus=3426,idx=65 ==> break
# bus=3426,idx=66 ==> break
# bus=3426,idx=67 ==> break
# bus=3426,idx=68 ==> break
# bus=3426,idx=69 ==> break
# bus=3426,idx=70 ==> break
# bus=3426,idx=71 ==> break
# bus=3426,idx=72 ==> break
# bus=3426,idx=73 ==> break
# bus=3426,idx=74 ==> break
# bus=3426,idx=75 ==> break
# bus=3426,idx=76 ==> break
# bus=3426,idx=77 ==> break
# bus=3426,idx=78 ==> break
# bus=3426,idx=79 ==> break
# bus=3426,idx=80 ==> break
# bus=3426,idx=81 ==> break
# bus=3426,idx=82 ==> break
# bus=3426,idx=83 ==> break
# bus=3426,idx=84 ==> break
# bus=3426,idx=85 ==> break
# bus=361,idx=59 ==> break
# bus=361,idx=60 ==> break
# bus=361,idx=61 ==> break
# bus=361,idx=62 ==> break
# bus=361,idx=63 ==> break
# bus=361,idx=64 ==> break
# bus=361,idx=65 ==> break
# bus=361,idx=66 ==> break
# bus=361,idx=67 ==> break
# bus=361,idx=68 ==> break
# bus=361,idx=69 ==> break
# bus=361,idx=70 ==> break
# bus=361,idx=71 ==> break
# bus=361,idx=72 ==> break
# bus=361,idx=73 ==> break
# bus=361,idx=74 ==> break
# bus=361,idx=75 ==> break
# bus=361,idx=76 ==> break
# bus=361,idx=77 ==> break
# bus=361,idx=78 ==> break
# bus=361,idx=79 ==> break
# bus=361,idx=80 ==> break
# bus=361,idx=81 ==> break
# bus=361,idx=82 ==> break
# bus=361,idx=83 ==> break
# bus=361,idx=84 ==> break
# bus=361,idx=85 ==> break
# bus=361,idx=86 ==> break
# bus=361,idx=87 ==> break
# bus=361,idx=88 ==> break
# bus=361,idx=89 ==> break
# bus=361,idx=90 ==> break
# bus=361,idx=91 ==> break
# bus=361,idx=92 ==> break
# bus=361,idx=93 ==> break
# bus=402,idx=61 ==> break
# bus=402,idx=62 ==> break
# bus=402,idx=63 ==> break
# bus=402,idx=64 ==> break
# bus=402,idx=65 ==> break
# bus=402,idx=66 ==> break
# bus=402,idx=67 ==> break
# bus=402,idx=68 ==> break
# bus=402,idx=69 ==> break
# bus=402,idx=70 ==> break
# bus=402,idx=71 ==> break
# bus=402,idx=72 ==> break
# bus=402,idx=73 ==> break
# bus=402,idx=74 ==> break
# bus=402,idx=75 ==> break
# bus=402,idx=76 ==> break
# bus=402,idx=77 ==> break
# bus=402,idx=78 ==> break
# bus=402,idx=79 ==> break
# bus=402,idx=80 ==> break
# bus=402,idx=81 ==> break
# bus=402,idx=82 ==> break
# bus=402,idx=83 ==> break
# bus=402,idx=84 ==> break
# bus=402,idx=85 ==> break
# bus=402,idx=86 ==> break
# bus=402,idx=87 ==> break
# bus=402,idx=88 ==> break
# bus=402,idx=89 ==> break
# bus=402,idx=90 ==> break
# bus=402,idx=91 ==> break
# bus=402,idx=92 ==> break
# bus=402,idx=93 ==> break
# bus=402,idx=94 ==> break
# bus=402,idx=95 ==> break
# bus=402,idx=96 ==> break
# bus=402,idx=97 ==> break
# bus=402,idx=98 ==> break
# bus=402,idx=99 ==> break
# bus=402,idx=100 ==> break
# bus=402,idx=101 ==> break
# bus=402,idx=102 ==> break
# bus=402,idx=103 ==> break
# bus=402,idx=104 ==> break
# bus=402,idx=105 ==> break
# bus=402,idx=106 ==> break
# bus=402,idx=107 ==> break
# bus=402,idx=108 ==> break
# bus=4425,idx=88 ==> break
# bus=4425,idx=89 ==> break
# bus=4425,idx=90 ==> break
# bus=4425,idx=91 ==> break
# bus=4425,idx=92 ==> break
# bus=4425,idx=93 ==> break
# bus=4425,idx=94 ==> break
# bus=4425,idx=95 ==> break
# bus=4425,idx=96 ==> break
# bus=4425,idx=97 ==> break
# bus=4425,idx=98 ==> break
# bus=4425,idx=99 ==> break
# bus=4425,idx=100 ==> break
# bus=4425,idx=101 ==> break
# bus=4425,idx=102 ==> break
# bus=4425,idx=103 ==> break
# bus=4425,idx=104 ==> break
# bus=4425,idx=105 ==> break
# bus=4425,idx=106 ==> break
# bus=4425,idx=107 ==> break
# bus=500,idx=62 ==> break
# bus=500,idx=63 ==> break
# bus=500,idx=64 ==> break
# bus=500,idx=65 ==> break
# bus=500,idx=66 ==> break
# bus=500,idx=67 ==> break
# bus=500,idx=68 ==> break
# bus=500,idx=69 ==> break
# bus=500,idx=70 ==> break
# bus=500,idx=71 ==> break
# bus=500,idx=72 ==> break
# bus=500,idx=73 ==> break
# bus=500,idx=74 ==> break
# bus=500,idx=75 ==> break
# bus=500,idx=76 ==> break
# bus=500,idx=77 ==> break
# bus=500,idx=78 ==> break
# bus=500,idx=79 ==> break
# bus=500,idx=80 ==> break
# bus=500,idx=81 ==> break
# bus=500,idx=82 ==> break
# bus=504,idx=74 ==> break
# bus=504,idx=75 ==> break
# bus=504,idx=76 ==> break
# bus=504,idx=77 ==> break
# bus=504,idx=78 ==> break
# bus=504,idx=79 ==> break
# bus=504,idx=80 ==> break
# bus=504,idx=81 ==> break
# bus=504,idx=82 ==> break
# bus=504,idx=83 ==> break
# bus=504,idx=84 ==> break
# bus=504,idx=85 ==> break
# bus=504,idx=86 ==> break
# bus=504,idx=87 ==> break
# bus=504,idx=88 ==> break
# bus=504,idx=89 ==> break
# bus=504,idx=90 ==> break
# bus=504,idx=91 ==> break
# bus=504,idx=92 ==> break
# bus=504,idx=93 ==> break
# bus=504,idx=94 ==> break
# bus=5535,idx=70 ==> break
# bus=5535,idx=71 ==> break
# bus=5535,idx=72 ==> break
# bus=5535,idx=73 ==> break
# bus=5535,idx=74 ==> break
# bus=5535,idx=75 ==> break
# bus=5535,idx=76 ==> break
# bus=5535,idx=77 ==> break
# bus=5535,idx=78 ==> break
# bus=5535,idx=79 ==> break
# bus=5535,idx=80 ==> break
# bus=6300,idx=81 ==> break
# bus=6300,idx=82 ==> break

# %%
src_df[src_df['노선명'] == bus_list[0]]
# Out:
#         ROUTE_ID  노선명   순번    NODE_ID  ARS_ID              정류소명         X좌표  \
# 143    100100063  402    1  123000354   24446           장지공영차고지  127.135886
# 1022   100100063  402    2  123000356   24448             아이코리아  127.133400
# 1605   100100063  402    3  123000372   24464   송파글마루도서관.버들어린이집  127.131555
# 2327   100100063  402    4  123000375   24467            문현고등학교  127.129206
# 3014   100100063  402    5  123000382   24475     장지역.가든파이브라이프동  127.124614
# ...          ...  ...  ...        ...     ...               ...         ...
# 39714  100100063  402  106  123000383   24476     장지역.가든파이브라이프동  127.124888
# 39816  100100063  402  107  123000374   24466  문현고등학교.송파파인타운5단지  127.129475
# 39891  100100063  402  108  123000373   24465   송파글마루도서관.버들어린이집  127.131337
# 39979  100100063  402  109  123000379   24471            아이코리아앞  127.133640
# 40054  100100063  402  110  123000355   24447           장지공영차고지  127.135645
#
#              Y좌표      시    구    동     거리
# 143    37.480507  서울특별시  송파구  장지동  377.0
# 1022   37.480972  서울특별시  송파구  장지동  190.0
# 1605   37.481607  서울특별시  송파구  장지동  271.0
# 2327   37.480709  서울특별시  송파구  장지동  450.0
# 3014   37.479072  서울특별시  송파구  문정동  795.0
# ...          ...    ...  ...  ...    ...
# 39714  37.479007  서울특별시  송파구  문정동  446.0
# 39816  37.480632  서울특별시  송파구  장지동  241.0
# 39891  37.481598  서울특별시  송파구  장지동  224.0
# 39979  37.480960  서울특별시  송파구  장지동  297.0
# 40054  37.480562  서울특별시  송파구  장지동    0.0
#
# [110 rows x 12 columns]

# %%
bus_list
# Out:
# ['3426',
#  '361',
#  '402',
#  '4425',
#  '500',
#  '504',
#  '5525',
#  '5535',
#  '6001',
#  '6005',
#  '6006',
#  '6007',
#  '6008',
#  '6009',
#  '6013',
#  '6016',
#  '6017',
#  '6019',
#  '6020',
#  '6103',
#  '6200',
#  '6300',
#  '6600',
#  '6703',
#  '6705A',
#  'N6703',
#  '강남03',
#  '강남06',
#  '강남06-1',
#  '강남06-2',
#  '서초06',
#  '서초16',
#  '서초17']

# %%
bus_list.pop(0)
# Out:
# '361'

# %%
print(f"'특정컬럼'의 값이 0.0인 행의 개수: {(src_df['거리'] == 0.0).sum()-705}")
# Out:
# '특정컬럼'의 값이 0.0인 행의 개수: 0

# %%
import pickle

def save_cache_to_pickle(cache, filename="distance_cache.pkl"):
  with open(filename, 'wb') as f: # 'wb'는 Write Binary 모드
    pickle.dump(cache, f)
  print(f"캐시가 '{filename}'에 Pickle 형식으로 저장되었습니다.")

# %%
save_cache_to_pickle(DISTANCE_CACHE_LOADED, "20251027_DISTANCE_CACHE.pkl")
# Out:
# 캐시가 '20251027_DISTANCE_CACHE.pkl'에 Pickle 형식으로 저장되었습니다.

# %%
print("DISTANCE_CACHE=",len(DISTANCE_CACHE_LOADED))
# Out:
# DISTANCE_CACHE= 17239

# %%
import math


def check_nan_in_dict(d):
    for value in d.values():
        # 값이 float 타입이고, math.isnan()을 통과하는지 확인
        if isinstance(value, float) and math.isnan(value):
            print()
            return True
    return False

result = check_nan_in_dict(DISTANCE_CACHE_LOADED)

print(f"DISTANCE_CACHE에 NaN이 있습니까?: {result}")
# Out:
# DISTANCE_CACHE에 NaN이 있습니까?: False

# %%
src_df.to_csv('20251027_서울시_버스정류장_주소_거리.csv', index=False, encoding='utf-8')
